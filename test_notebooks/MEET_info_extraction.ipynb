# %% [markdown]
# # Testing prompts for Classifying emails

# %% [markdown]
# ## Importing libraries

# %%
import os
import numpy as np
import requests
from dotenv import load_dotenv
from langsmith import traceable
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    accuracy_score, confusion_matrix, hamming_loss
)
import re

import warnings
warnings.filterwarnings("ignore")

### Getting Path of current file
import os
import sys
from pathlib import Path

path = Path(os.path.dirname(os.getcwd()))
path = str(path)
print(path)
sys.path.insert(1, path)
# Out:
# /Users/saideepbunny/Projects/Email-Assistant-using-Generative-AI

# %% [markdown]
# ## Setting API keys

# %%
load_dotenv(dotenv_path=f"{path}/config/nvidia_token.env")

model1 = "google/gemma-3n-e4b-it"
model2 = "mistralai/mistral-nemotron"
model3 = "moonshotai/kimi-k2-instruct"

token = os.getenv("NVIDIA_API_KEY")

# %% [markdown]
# ## Classification function

# %%
def classify_email(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Classify emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Cleaned classification result (only capital letters).
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{{email_content}}\n\n{prompt_msg}"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})

    # Extract only capital letters (JOB, MEET, OTHER)
    clean_result = re.sub(r'[^A-Za-z,]+', '', result)
    final_result = clean_result.split(",")
    return np.array(final_result)

# %% [markdown]
# ## Information extraction function

# %%
def extract_MEET_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{prompt_msg}\n\n EMAIL TO ANALYZE: {{email_content}} \n\n PIPE-DELIMITED OUTPUT:"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.0,
        top_p=1.0,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.split("|"))


def meet_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_MEET']) == True:
        result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
        if(len(result) != 6):
            print(result)
            return np.array(["Error"] * 6)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan])

# %%
df = pd.read_excel(f"{path}/data/email_classification_annotated_data.xlsx", sheet_name="updated_annotated_data")
df
# Out:
#                                                 email    JOB   MEET  OTHER
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False

# %% [markdown]
# ## Email Classification

# %%
prompt = """You are an expert email class identification system. Your task is to analyze the provided email and identify if the email falls it each category or not. Your response must be **only** the True/False for each category without any additional text or metadata.

### **Categories**

**1. JOB**
Identify an email as `JOB` if it concerns the status of a specific job application. Recipient of the mail will be informed about the status of their application. This includes notifications that a candidate has:
*   Successfully applied/in the process of applying for a job (application confirmation).
*   Been shortlisted for a position.
*   Been invited to an interview or assessment.
*   Been rejected for a position.
*   Job recommendations or suggestions or ads from job boards, recruiters, companies, etc., do not classify as JOB.

**2. MEET**
Identify an email as `MEET` if the sender is requesting to schedule a meeting, virtual or in-person.
*   Can be a virtual meeting via Zoom, Google Meet, Teams, Video call, etc.
*   Can be an in-person meeting at a specific location.
*   Can be an invitation to job interviews, assessments as well.
*   Cannot be classified as MEET unless it is mentioned explicitly in the email. Future steps of a process or a job application having a meeting do not classify as MEET.

**3. OTHER**
Identify an email as `OTHER` only if it does not fit into the `JOB` or `MEET` categories. This includes, but is not limited to:
*   General job-related discussions that are not about application status (e.g., networking, asking about a role, advertisements, job suggestions or requesting for an interview).
*   Newsletters, marketing emails, personal correspondence, etc.

**Important Rules:**
*   An email cannot be identified as any other class if it classifies as OTHER.
*   An email can be identified as either JOB or either MEET or both JOB and MEET.
*   Possible combinations of classes for email are:
    *   JOB, MEET
    *   JOB
    *   MEET
    *   OTHER

### **Output Format**

Your answer must be three True or False values, one for each JOB, MEET and OTHER in this exact order:
<is a JOB>, <is a MEET>, <is OTHER>"""

# %%
data_df = df.copy()
data_df[['mistral_JOB', 'mistral_MEET', 'mistral_OTHER']] = (
    data_df['email']
    .apply(lambda x: classify_email(model2, token, prompt, x))
    .apply(pd.Series)  # convert array to 3 separate columns
)

# %%
data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER
# 0         True        False         False
# 1         True        False         False
# 2         True        False         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False

# %% [markdown]
# ## Information extraction

# %% [markdown]
# ### Prompt-1 test

# %%
info_extract_prompt1 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Meet start time — start time of the meeting if specified in the email.
3. Meet end time — end time of the meeting if specified in the email.
4. Total duration — Total duration of the meeting if specified in the email.
5. Meeting requested date - The date when the meeting was requested/ scheduled if specified in the mail.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 6 values separated by a pipe (|).

### Output format:
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>

Return the extracted information in the format above, with each detail separated by a pipe, without any additional text or metadata. If any detail is not present in the email, return an empty string for that detail (e.g., if the meet start time, end time and total duration is not mentioned, return <request_sent_by>||||<meeting_requested_date>|<reason_for_meeting>."""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Elena' '' '' '2023-03-08' 'Denver warehouse optimization idea']
# ['Michael Rodriguez' '' '' '30 minutes' '' ''
#  'Discuss potential synergies and predictive modeling']
# ['David Park' '' '' '30 minutes' '' '' 'Discuss dissertation proposal']
# ['Rakshitha' '' '' '1 hour' '' ''
#  'Grad Coop interview for Data Scientist/Engineer']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Error
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False                       Error
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                       Error
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                       Error
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#    meet_start_time meet_end_time total_duration meeting_requested_date  \
# 0              NaN           NaN            NaN                    NaN
# 1              NaN           NaN            NaN                    NaN
# 2              NaN           NaN            NaN                    NaN
# 3              NaN           NaN            NaN                    NaN
# 4              NaN           NaN            NaN                    NaN
# 5              NaN           NaN            NaN                    NaN
# 6              NaN           NaN            NaN                    NaN
# 7              NaN           NaN            NaN                    NaN
# 8              NaN           NaN            NaN                    NaN
# 9              NaN           NaN            NaN                    NaN
# 10                    30 minutes
# 11           Error         Error          Error                  Error
# 12
# 13                    20 minutes
# 14           Error         Error          Error                  Error
# 15                      9 AM EST         1 hour               Thursday
# 16                    45 minutes
# 17
# 18                      1 PM EST     90 minutes   Tuesday, August 15th
# 19                    25 minutes
# 20             NaN           NaN            NaN                    NaN
# 21             NaN           NaN            NaN                    NaN
# 22             NaN           NaN            NaN                    NaN
# 23             NaN           NaN            NaN                    NaN
# 24             NaN           NaN            NaN                    NaN
# 25             NaN           NaN            NaN                    NaN
# 26             NaN           NaN            NaN                    NaN
# 27             NaN           NaN            NaN                    NaN
# 28             NaN           NaN            NaN                    NaN
# 29             NaN           NaN            NaN                    NaN
# 30             NaN           NaN            NaN                    NaN
# 31
# 32
# 33                                         3 PM                  today
# 34                                                       this Saturday
# 35           Error         Error          Error                  Error
# 36             NaN           NaN            NaN                    NaN
# 37             NaN           NaN            NaN                    NaN
# 38             NaN           NaN            NaN                    NaN
# 39             NaN           NaN            NaN                    NaN
# 40     2:00 PM EST   3:00 PM EST     60 minutes   Thursday, March 14th
# 41        10:30 AM      12:00 PM     90 minutes    Tuesday, March 12th
# 42
# 43           Error         Error          Error                  Error
# 44                                                            May 24th
# 45             NaN           NaN            NaN                    NaN
# 46             NaN           NaN            NaN                    NaN
# 47             NaN           NaN            NaN                    NaN
# 48             NaN           NaN            NaN                    NaN
# 49             NaN           NaN            NaN                    NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                 Discuss Morrison campaign insights
# 11                                              Error
# 12             Review digital transformation progress
# 13  Barcelona client contract international law ex...
# 14                                              Error
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17          Discuss documentary project collaboration
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19              gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      Discuss Q3 marketing strategy
# 32                          Coffee meetup and updates
# 33               Discuss client situation immediately
# 34                   Meet for pastries reconnaissance
# 35                                              Error
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42             Data Science Intern position interview
# 43                                              Error
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Michael Rodriguez' '' '' '' '30-minute' ''
#  'Discuss potential synergies between Zenith Solutions and Brightwave Analytics']
# ['Alex' '' '9 AM EST' '' 'about an hour' 'this Thursday'
#  'Review mobile app redesign wireframes']
# ['Patricia Gonzalez' '' '' '' '45-minute' ''
#  'Evaluate logistics partnership for East Coast distribution']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[11], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      53 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_MEET']) == True:
# ---> 55         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      56         if(len(result) != 6):
#      57             print(result)
#
# Cell In[4], line 49, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %% [markdown]
# ### Prompt-2 test

# %%
info_extract_prompt2 = """
You are an information extraction assistant.  
You will receive the full text of an email containing a meeting request.  
This may be for a virtual meeting, in-person meeting, or job interview.

Your task:  
Read the email carefully and extract the following details exactly as they appear in the email.  
If a detail is not mentioned, return an empty string for that field.

Fields to extract (in order):  
1. Request sent by – Name of the person or organization requesting the meeting.  
2. Meet start time – Start time of the meeting.  
3. Meet end time – End time of the meeting.  
4. Total duration – Total duration of the meeting.  
5. Meeting requested date – Date the meeting is scheduled/requested.  
6. Reason for meeting – Summarize in ≤15 words.

**Output format:**  
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>  

**Rules:**  
- There must be exactly 6 values separated by 5 pipe (|) characters.
- Use exactly the wording from the email for all fields except “Reason for meeting,” which should be a concise summary.  
- Do not add extra words, punctuation, or formatting outside the specified structure.  
- Maintain the order of fields exactly as shown.  
- If a value is missing, leave it blank but keep the pipe separators.  
- The output must be a single line only.

Example:  
If only the requester's name, requested date, and reason are present, return:  
John Smith||||2024-08-15|Discuss project timeline
"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Elena' '' '2 PM PST' '' '' 'Wednesday'
#  'Denver warehouse optimization idea']
# ['Michael Rodriguez' '' '' '30 minutes' '' ''
#  'Discuss potential synergies']
# ['Patricia Gonzalez' '' '' '45 minutes' '' ''
#  'Discuss logistics partnership']
# ['Samantha' '' '' '25 minutes' '' ''
#  'Discuss gamifying employee onboarding']
# ['Michelle' '' '3 PM' '' '' 'today' 'Discuss client situation']
# ['David Park' '' '' '30 minutes' '' '' 'Dissertation proposal discussion']
# ['Rakshitha' '' '' '1 hour' '' '' 'Grad Coop interview']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Error
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False                       Error
# 15       False         True         False                        Alex
# 16       False         True         False                       Error
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                       Error
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                       Error
# 34       False         True         False                 Agent Jones
# 35       False         True         False                       Error
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                       Error
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#    meet_start_time meet_end_time total_duration meeting_requested_date  \
# 0              NaN           NaN            NaN                    NaN
# 1              NaN           NaN            NaN                    NaN
# 2              NaN           NaN            NaN                    NaN
# 3              NaN           NaN            NaN                    NaN
# 4              NaN           NaN            NaN                    NaN
# 5              NaN           NaN            NaN                    NaN
# 6              NaN           NaN            NaN                    NaN
# 7              NaN           NaN            NaN                    NaN
# 8              NaN           NaN            NaN                    NaN
# 9              NaN           NaN            NaN                    NaN
# 10
# 11           Error         Error          Error                  Error
# 12
# 13
# 14           Error         Error          Error                  Error
# 15                      9 AM EST         1 hour               Thursday
# 16           Error         Error          Error                  Error
# 17
# 18        1 PM EST   2:30 PM EST     90 minutes             2024-08-15
# 19           Error         Error          Error                  Error
# 20             NaN           NaN            NaN                    NaN
# 21             NaN           NaN            NaN                    NaN
# 22             NaN           NaN            NaN                    NaN
# 23             NaN           NaN            NaN                    NaN
# 24             NaN           NaN            NaN                    NaN
# 25             NaN           NaN            NaN                    NaN
# 26             NaN           NaN            NaN                    NaN
# 27             NaN           NaN            NaN                    NaN
# 28             NaN           NaN            NaN                    NaN
# 29             NaN           NaN            NaN                    NaN
# 30             NaN           NaN            NaN                    NaN
# 31
# 32
# 33           Error         Error          Error                  Error
# 34           10 AM                                       this Saturday
# 35           Error         Error          Error                  Error
# 36             NaN           NaN            NaN                    NaN
# 37             NaN           NaN            NaN                    NaN
# 38             NaN           NaN            NaN                    NaN
# 39             NaN           NaN            NaN                    NaN
# 40     2:00 PM EST   3:00 PM EST     60 minutes             March 14th
# 41        10:30 AM      12:00 PM     90 minutes    Tuesday, March 12th
# 42
# 43           Error         Error          Error                  Error
# 44     1:30 PM EST                                          2024-05-24
# 45             NaN           NaN            NaN                    NaN
# 46             NaN           NaN            NaN                    NaN
# 47             NaN           NaN            NaN                    NaN
# 48             NaN           NaN            NaN                    NaN
# 49             NaN           NaN            NaN                    NaN
#
#                          reason_for_meeting
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10       Discuss Morrison campaign insights
# 11                                    Error
# 12  Discuss digital transformation progress
# 13          Barcelona client contract issue
# 14                                    Error
# 15    Review mobile app redesign wireframes
# 16                                    Error
# 17        Discuss documentary collaboration
# 18      Q4 strategy and Stellar acquisition
# 19                                    Error
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# 31            Discuss Q3 marketing strategy
# 32     Catch up and discuss startup updates
# 33                                    Error
# 34           Reconnaissance on new pastries
# 35                                    Error
# 36                                      NaN
# 37                                      NaN
# 38                                      NaN
# 39                                      NaN
# 40              Marketing Manager interview
# 41             Software Developer interview
# 42              Phone screen for internship
# 43                                    Error
# 44        Interview with Dr. James Shanahan
# 45                                      NaN
# 46                                      NaN
# 47                                      NaN
# 48                                      NaN
# 49                                      NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Marcus' '' '' '' '' '' 'Review Morrison campaign focus-group findings']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[14], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      53 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_MEET']) == True:
# ---> 55         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      56         if(len(result) != 6):
#      57             print(result)
#
# Cell In[4], line 49, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %%
info_extract_prompt3 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Meet start time — start time of the meeting if specified in the email.
3. Meet end time — end time of the meeting if specified in the email.
4. Total duration — Total duration of the meeting if specified in the email.
5. Meeting requested date - The date when the meeting was requested/ scheduled if specified in the mail.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 6 values separated by a pipe (|).

### Output format:
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Jake' '' '' '20 minutes' '' ''
#  'Barcelona client contract expertise needed']
# ['David Park' '' '' '30 minutes' '' '' 'Discuss dissertation proposal']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                       Error
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                       Error
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#    meet_start_time meet_end_time  \
# 0              NaN           NaN
# 1              NaN           NaN
# 2              NaN           NaN
# 3              NaN           NaN
# 4              NaN           NaN
# 5              NaN           NaN
# 6              NaN           NaN
# 7              NaN           NaN
# 8              NaN           NaN
# 9              NaN           NaN
# 10       10 AM EST      4 PM EST
# 11
# 12       11 AM EST      3 PM EST
# 13           Error         Error
# 14              ""            ""
# 15        9 AM EST     10 AM EST
# 16            9 AM          3 PM
# 17
# 18        1 PM EST   2:30 PM EST
# 19
# 20             NaN           NaN
# 21             NaN           NaN
# 22             NaN           NaN
# 23             NaN           NaN
# 24             NaN           NaN
# 25             NaN           NaN
# 26             NaN           NaN
# 27             NaN           NaN
# 28             NaN           NaN
# 29             NaN           NaN
# 30             NaN           NaN
# 31
# 32
# 33            3 PM            ""
# 34                         10 AM
# 35           Error         Error
# 36             NaN           NaN
# 37             NaN           NaN
# 38             NaN           NaN
# 39             NaN           NaN
# 40     2:00 PM EST   3:00 PM EST
# 41        10:30 AM      12:00 PM
# 42
# 43
# 44     1:30 PM EST            ""
# 45             NaN           NaN
# 46             NaN           NaN
# 47             NaN           NaN
# 48             NaN           NaN
# 49             NaN           NaN
#
#                                    total_duration meeting_requested_date  \
# 0                                             NaN                    NaN
# 1                                             NaN                    NaN
# 2                                             NaN                    NaN
# 3                                             NaN                    NaN
# 4                                             NaN                    NaN
# 5                                             NaN                    NaN
# 6                                             NaN                    NaN
# 7                                             NaN                    NaN
# 8                                             NaN                    NaN
# 9                                             NaN                    NaN
# 10                                     30 minutes
# 11                                       2 PM PST              Wednesday
# 12                                     45 minutes     August 8th or 11th
# 13                                          Error                  Error
# 14                                      30-minute                     ""
# 15                                         1 hour               Thursday
# 16                                      45-minute                     ""
# 17  Tuesday at 4 PM PST or Wednesday at 10 AM PST
# 18                                     90 minutes   Tuesday, August 15th
# 19                                     25 minutes              this week
# 20                                            NaN                    NaN
# 21                                            NaN                    NaN
# 22                                            NaN                    NaN
# 23                                            NaN                    NaN
# 24                                            NaN                    NaN
# 25                                            NaN                    NaN
# 26                                            NaN                    NaN
# 27                                            NaN                    NaN
# 28                                            NaN                    NaN
# 29                                            NaN                    NaN
# 30                                            NaN                    NaN
# 31
# 32
# 33                                             ""                  today
# 34                                                              Saturday
# 35                                          Error                  Error
# 36                                            NaN                    NaN
# 37                                            NaN                    NaN
# 38                                            NaN                    NaN
# 39                                            NaN                    NaN
# 40                                     60 minutes             March 14th
# 41                                     90 minutes    Tuesday, March 12th
# 42                                  30-45 minutes
# 43                                         1 hour
# 44                                             ""               May 24th
# 45                                            NaN                    NaN
# 46                                            NaN                    NaN
# 47                                            NaN                    NaN
# 48                                            NaN                    NaN
# 49                                            NaN                    NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                 Discuss Morrison campaign insights
# 11                 Denver warehouse optimization idea
# 12             Review digital transformation progress
# 13                                              Error
# 14  Discuss potential synergies and predictive mod...
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17          Discuss documentary project collaboration
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19              Gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      Discuss Q3 marketing strategy
# 32                  Coffee meetup and startup updates
# 33               Discuss client situation immediately
# 34                     secret location reconnaissance
# 35                                              Error
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42                      Data Science Intern interview
# 43                Technical interview and online test
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Marcus' '' '30-minute' '' 'Tuesday through Thursday 10 AM-4 PM EST' ''
#  'Review Morrison campaign focus group insights']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[17], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      53 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_MEET']) == True:
# ---> 55         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      56         if(len(result) != 6):
#      57             print(result)
#
# Cell In[4], line 49, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %%
def extract_MEET_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
       f"""{prompt_msg}\n\n EMAIL TO ANALYZE: {{email_content}} \n\n PIPE-DELIMITED OUTPUT:"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.strip().split("|"))


def meet_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_MEET']) == True:
        result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
        if(len(result) != 3):
            print(result)
            return np.array(["Error"] * 3)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan])

# %% [markdown]
# ### Prompt-3 test

# %%
info_extract_prompt3 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Requested date and time - The date and time when the meeting is requested to be held. Make sure to return the exact content if specified.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 3 values separated by a pipe (|).

### Output format:
<request_sent_by>|<requested_date_time>|<reason_for_meeting>"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                      Kahlil
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                   requested_date_time  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  next week, Tuesday through Thursday between 10...
# 11                              Wednesday at 2 PM PST
# 12                   Friday, August 8th at 11 AM EST
# 13         today until 6 PM or early tomorrow morning
# 14                                     next two weeks
# 15                          this Thursday at 9 AM EST
# 16              between 9 AM and 3 PM EST on weekdays
# 17  this Tuesday at 4 PM PST or Wednesday at 10 AM...
# 18                   Tuesday, August 15th at 1 PM EST
# 19              Wednesday afternoon or Friday morning
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                next Tuesday or Wednesday afternoon
# 32                                          this week
# 33                                         3 PM today
# 34                             this Saturday at 10 AM
# 35                                          next week
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                Thursday, March 14th at 2:00 PM EST
# 41           Tuesday, March 12th, 10:30 AM - 12:00 PM
# 42                                  this week or next
# 43   today till Friday anytime between 3 PM -6 PM EST
# 44                            May 24th at 1:30 PM EST
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  discuss preliminary data from Morrison campaig...
# 11                 Denver warehouse optimization idea
# 12   monthly review meeting to discuss digital tra...
# 13  Barcelona client contract, international law e...
# 14  discuss potential synergies between our compan...
# 15              review mobile app redesign wireframes
# 16  discuss requirements and learn about capabilities
# 17  discussing potential collaboration on a docume...
# 18  Q4 strategic initiatives and potential acquisi...
# 19  discuss gamifying the employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                  discuss our Q3 marketing strategy
# 32                         catch up and share updates
# 33           discuss the client situation immediately
# 34                     reconnaissance of new pastries
# 35  discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Interview for Marketing Manager position, cove...
# 41                       Software Developer interview
# 42      phone screen for Data Science Intern position
# 43  initial round of interviews for Grad Coop for ...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Alex' 'this week' '' '']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                       Error
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                   requested_date_time  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  next week, Tuesday through Thursday between 10...
# 11                   tomorrow (Wednesday) at 2 PM PST
# 12  Friday, August 8th at 11 AM EST or Monday, Aug...
# 13
# 14  weekday mornings before 11 AM PST or after 2 P...
# 15                               Thursday at 9 AM EST
# 16                      9 AM and 3 PM EST on weekdays
# 17      Tuesday at 4 PM PST or Wednesday at 10 AM PST
# 18                   Tuesday, August 15th at 1 PM EST
# 19
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31
# 32                                              Error
# 33                                         3 PM today
# 34                             this Saturday at 10 AM
# 35
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                Thursday, March 14th at 2:00 PM EST
# 41           Tuesday, March 12th, 10:30 AM - 12:00 PM
# 42
# 43
# 44                            May 24th at 1:30 PM EST
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                 Discuss Morrison campaign insights
# 11                 Denver warehouse optimization idea
# 12  Discuss digital transformation progress and mi...
# 13                  Discuss Barcelona client contract
# 14  Discuss potential synergies and predictive mod...
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17                        Discuss documentary project
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19              gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      discuss Q3 marketing strategy
# 32                                              Error
# 33               Discuss client situation immediately
# 34                        reconnaissance new pastries
# 35                      discuss dissertation proposal
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42   phone interview for Data Science Intern position
# 43    Grad Coop interview for Data Scientist/Engineer
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[22], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[18], line 54, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      52 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      53     if eval(row['mistral_MEET']) == True:
# ---> 54         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      55         if(len(result) != 3):
#      56             print(result)
#
# Cell In[18], line 48, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      45 chain = prompt | llm | StrOutputParser()
#      47 # Run it
# ---> 48 result = chain.invoke({"email_content": email_content})
#      49 return np.array(result.strip().split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %% [markdown]
# ### Prompt-4 test

# %%
def extract_MEET_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{prompt_msg}\n\n EMAIL TO ANALYZE: {{email_content}} \n\n PIPE-DELIMITED OUTPUT:"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.0,
        top_p=1.0,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.split("|"))


def meet_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_MEET']) == True:
        result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
        if(len(result) != 5):
            print(result)
            return np.array(["Error"] * 5)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan, np.nan, np.nan])

# %%
info_extract_prompt4 = """You are an expert information extraction assistant.

You will be given the full text of an email about a meeting request. You will also be given the current date and time for context to resolve relative dates (e.g., "tomorrow").

Your task is to read the email carefully and extract the following details.

Fields to Extract (in order):
request_sent_by: The name of the person or organization requesting the meeting.

meeting_date: The full date or date range of the meeting. Convert relative dates into YYYY-MM-DD format. For a range, use YYYY-MM-DD to YYYY-MM-DD.

start_time: The meeting's start time, normalized to a 24-hour HH:MM format.

end_time: The meeting's end time, normalized to a 24-hour HH:MM format. If only a start time and duration are given (e.g., "a 1-hour meeting at 2 PM"), you must calculate and format the end time.

reason_for_meeting: A concise summary of the meeting's purpose in 15 words or less.

Output Format:
Provide the output as a single line of pipe-delimited (|) text. If a detail is not mentioned, leave the field blank.

<request_sent_by>|<meeting_date>|<start_time>|<end_time>|<reason_for_meeting>

Rules:
There must be exactly 5 values separated by 4 pipe (|) characters.

Time and Date Formatting is Strict:

meeting_date must be YYYY-MM-DD for a single day or YYYY-MM-DD to YYYY-MM-DD for a range.

start_time and end_time must be HH:MM (24-hour clock). For example, "3 PM" becomes "15:00".

Handle Ambiguity: If the email proposes a range of possible dates or a window of time, extract the date range into the meeting_date field. Leave start_time and end_time blank unless a specific, single meeting slot is confirmed.

If a value is missing, leave it blank but keep the pipe separators. For example: Jane Smith|2025-08-26|||Catch up on project status.

The output must be a single line only. Do not add any extra words or explanations.

Examples:
Current Context: Monday, August 25, 2025, 10:00 AM.

Example Email 1:
"Hi team, I'd like to schedule a meeting for tomorrow, August 26th, from 2:00 PM to 3:30 PM to review the quarterly budget. Let me know if that works. Best, Sarah Chen"

Correct Output 1:
Sarah Chen|2025-08-26|14:00|15:30|Review the quarterly budget

Example Email 2:
"Hello, This is a confirmation from Acme Corp for your interview on Wednesday at 11 AM. The interview will last for 45 minutes. We look forward to speaking with you."

Correct Output 2:
Acme Corp|2025-08-27|11:00|11:45|Interview confirmation

Example Email 3:
"Hi Pat, Following up on our call. Can we connect to discuss the project proposal? Let me know what time works for you. -Alex"

Correct Output 3:
Alex|||||Discuss the project proposal

Example Email 4 (Handling a Window):
"Hi Mark, Are you free to connect sometime this week to go over the new designs? I'm generally available from Wednesday to Friday between 9 AM and noon. Let me know what works. -Jen"

Correct Output 4:
Jen|2025-08-27 to 2025-08-29|||Go over the new designs"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Alex' '' '' '' '' 'Catch up and share updates\n']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                       Error
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Smith
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                      Kahlil
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#       meeting_requested_date meet_start_time meet_end_time  \
# 0                        NaN             NaN           NaN
# 1                        NaN             NaN           NaN
# 2                        NaN             NaN           NaN
# 3                        NaN             NaN           NaN
# 4                        NaN             NaN           NaN
# 5                        NaN             NaN           NaN
# 6                        NaN             NaN           NaN
# 7                        NaN             NaN           NaN
# 8                        NaN             NaN           NaN
# 9                        NaN             NaN           NaN
# 10  2025-08-26 to 2025-08-28           10:00         10:30
# 11                2025-08-27           14:00         14:00
# 12                2025-08-08           11:00         11:45
# 13                2025-08-25           12:00         12:20
# 14  2025-08-28 to 2025-09-10           09:00         09:30
# 15                2025-08-28           09:00         10:00
# 16  2025-08-26 to 2025-08-28           09:00         15:00
# 17                2025-08-26           16:00         17:00
# 18                2025-08-15           13:00         14:30
# 19  2025-08-27 to 2025-08-29           14:00         14:25
# 20                       NaN             NaN           NaN
# 21                       NaN             NaN           NaN
# 22                       NaN             NaN           NaN
# 23                       NaN             NaN           NaN
# 24                       NaN             NaN           NaN
# 25                       NaN             NaN           NaN
# 26                       NaN             NaN           NaN
# 27                       NaN             NaN           NaN
# 28                       NaN             NaN           NaN
# 29                       NaN             NaN           NaN
# 30                       NaN             NaN           NaN
# 31  2025-08-26 to 2025-08-27
# 32                     Error           Error         Error
# 33                2025-08-25           15:00
# 34                2025-08-30           10:00         10:00
# 35  2025-08-26 to 2025-08-29
# 36                       NaN             NaN           NaN
# 37                       NaN             NaN           NaN
# 38                       NaN             NaN           NaN
# 39                       NaN             NaN           NaN
# 40                2024-03-14           14:00         15:00
# 41                2025-03-12           10:30         12:00
# 42  2025-08-25 to 2025-08-31
# 43  2025-08-25 to 2025-08-29           15:00         16:00
# 44                2024-05-24           13:30         14:00
# 45                       NaN             NaN           NaN
# 46                       NaN             NaN           NaN
# 47                       NaN             NaN           NaN
# 48                       NaN             NaN           NaN
# 49                       NaN             NaN           NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Discuss Morrison campaign insights and messagi...
# 11                    Denver warehouse optimization\n
# 12  Discuss digital transformation progress and mi...
# 13                  Discuss Barcelona client contract
# 14  Discuss potential synergies between our companies
# 15              Design sync for mobile app redesign\n
# 16         Discuss logistics partnership requirements
# 17   Discuss potential collaboration on a documentary
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19    Discuss gamifying employee onboarding process\n
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      Discuss Q3 marketing strategy
# 32                                              Error
# 33                     Discuss the client situation\n
# 34                   Reconnaissance of new pastries\n
# 35                      Discuss dissertation proposal
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40           Interview for Marketing Manager position
# 41                       Software Developer interview
# 42      Phone screen for Data Science Intern position
# 43  Initial technical interview for Data Scientist...
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Patricia Gonzalez' '' '' '' ''
#  'Discuss logistics partnership requirements']
# ['Alex' '' '' '' '' 'Catch up over coffee']
# ['Kahlil John Somera' '' '' '' '' 'Phone screen for internship']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False                       Error
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                       Error
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                       Error
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#       meeting_requested_date meet_start_time meet_end_time  \
# 0                        NaN             NaN           NaN
# 1                        NaN             NaN           NaN
# 2                        NaN             NaN           NaN
# 3                        NaN             NaN           NaN
# 4                        NaN             NaN           NaN
# 5                        NaN             NaN           NaN
# 6                        NaN             NaN           NaN
# 7                        NaN             NaN           NaN
# 8                        NaN             NaN           NaN
# 9                        NaN             NaN           NaN
# 10  2025-09-02 to 2025-09-04
# 11                2025-08-27           14:00         14:30
# 12  2025-08-08 to 2025-08-11
# 13                                                   18:00
# 14  2025-08-25 to 2025-09-08
# 15                2025-08-28           09:00         10:00
# 16                     Error           Error         Error
# 17  2025-08-26 or 2025-08-27
# 18                2025-08-15           13:00         14:30
# 19  2025-08-27 to 2025-08-29
# 20                       NaN             NaN           NaN
# 21                       NaN             NaN           NaN
# 22                       NaN             NaN           NaN
# 23                       NaN             NaN           NaN
# 24                       NaN             NaN           NaN
# 25                       NaN             NaN           NaN
# 26                       NaN             NaN           NaN
# 27                       NaN             NaN           NaN
# 28                       NaN             NaN           NaN
# 29                       NaN             NaN           NaN
# 30                       NaN             NaN           NaN
# 31  2025-09-02 to 2025-09-03
# 32                     Error           Error         Error
# 33                2025-08-25           15:00         15:30
# 34                2025-08-30           10:00
# 35  2025-09-01 to 2025-09-05
# 36                       NaN             NaN           NaN
# 37                       NaN             NaN           NaN
# 38                       NaN             NaN           NaN
# 39                       NaN             NaN           NaN
# 40                2025-03-14           14:00         15:00
# 41                2025-03-12           10:30         12:00
# 42                     Error           Error         Error
# 43  2025-08-25 to 2025-08-29
# 44                2025-05-24           13:30         14:30
# 45                       NaN             NaN           NaN
# 46                       NaN             NaN           NaN
# 47                       NaN             NaN           NaN
# 48                       NaN             NaN           NaN
# 49                       NaN             NaN           NaN
#
#                           reason_for_meeting
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10        Discuss Morrison campaign insights
# 11        Denver warehouse optimization idea
# 12   Discuss digital transformation progress
# 13         Discuss Barcelona client contract
# 14               Discuss potential synergies
# 15                Review mobile app redesign
# 16                                     Error
# 17         Discuss documentary collaboration
# 18  Q4 strategic initiatives and acquisition
# 19     Gamifying employee onboarding process
# 20                                       NaN
# 21                                       NaN
# 22                                       NaN
# 23                                       NaN
# 24                                       NaN
# 25                                       NaN
# 26                                       NaN
# 27                                       NaN
# 28                                       NaN
# 29                                       NaN
# 30                                       NaN
# 31             Discuss Q3 marketing strategy
# 32                                     Error
# 33              Discuss the client situation
# 34            Reconnaissance on new pastries
# 35             Discuss dissertation proposal
# 36                                       NaN
# 37                                       NaN
# 38                                       NaN
# 39                                       NaN
# 40               Marketing Manager interview
# 41          Interview for Software Developer
# 42                                     Error
# 43       Technical interview and online test
# 44         Interview with Dr. James Shanahan
# 45                                       NaN
# 46                                       NaN
# 47                                       NaN
# 48                                       NaN
# 49                                       NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Jake' '2025-08-25' '' '' '' 'Discuss Barcelona client contract issue']
# ['Patricia Gonzalez' '' '' '' ''
#  'Introductory call to discuss logistics partnership']
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[27], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by', 'meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[23], line 55, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      53 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_MEET']) == True:
# ---> 55         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      56         if(len(result) != 5):
#      57             print(result)
#
# Cell In[23], line 49, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %% [markdown]
# ### Prompt-5 test

# %%
info_extract_prompt5 = """You are an expert information extraction assistant.

You will be given the full text of an email about a meeting request.

Your task is to read the email carefully and extract the following details.

Fields to Extract (in order):
request_sent_by: The name of the person or organization requesting the meeting.

meeting_date: The date or date range of the meeting, extracted exactly as it appears in the text (e.g., "tomorrow", "Wednesday", "August 26th", "Wednesday to Friday").

start_time: The meeting's start time, normalized to a 24-hour HH:MM format.

end_time: The meeting's end time, normalized to a 24-hour HH:MM format. If only a start time and duration are given (e.g., "a 1-hour meeting at 2 PM"), you must calculate and format the end time.

reason_for_meeting: A concise summary of the meeting's purpose in 15 words or less.

Output Format:
Provide the output as a single line of pipe-delimited (|) text. If a detail is not mentioned, leave the field blank.

<request_sent_by>|<meeting_date>|<start_time>|<end_time>|<reason_for_meeting>

Rules:
There must be exactly 5 values separated by 4 pipe (|) characters.

Time Formatting is Strict:

start_time and end_time must be HH:MM (24-hour clock). For example, "3 PM" becomes "15:00".

Handle Ambiguity: If the email proposes a range of possible dates or a window of time, extract the date range into the meeting_date field. Leave start_time and end_time blank unless a specific, single meeting slot is confirmed.

If a value is missing, leave it blank but keep the pipe separators. For example: Jane Smith|August 26th|||Catch up on project status.

The output must be a single line only. Do not add any extra words or explanations.

Examples:
Example Email 1:
"Hi team, I'd like to schedule a meeting for tomorrow, August 26th, from 2:00 PM to 3:30 PM to review the quarterly budget. Let me know if that works. Best, Sarah Chen"

Correct Output 1:
Sarah Chen|tomorrow, August 26th|14:00|15:30|Review the quarterly budget

Example Email 2:
"Hello, This is a confirmation from Acme Corp for your interview on Wednesday at 11 AM. The interview will last for 45 minutes. We look forward to speaking with you."

Correct Output 2:
Acme Corp|Wednesday|11:00|11:45|Interview confirmation

Example Email 3:
"Hi Pat, Following up on our call. Can we connect to discuss the project proposal? Let me know what time works for you. -Alex"

Correct Output 3:
Alex|||||Discuss the project proposal

Example Email 4 (Handling a Window):
"Hi Mark, Are you free to connect sometime this week to go over the new designs? I'm generally available from Wednesday to Friday between 9 AM and noon. Let me know what works. -Jen"

Correct Output 4:
Jen|Wednesday to Friday|||Go over the new designs"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt5, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Alex' 'this week' '' '' '' 'Catch up and share updates\n']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                       Error
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Smith
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                      Kahlil
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                meeting_requested_date meet_start_time  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                                Tuesday to Thursday           10:00
# 11                               tomorrow (Wednesday)           14:00
# 12  Friday, August 8th at 11 AM EST, Monday, Augus...           11:00
# 13                      today, early tomorrow morning
# 14                                      last Thursday           09:00
# 15                                           Thursday           09:00
# 16                 weekdays between 9 AM and 3 PM EST
# 17                                 Tuesday, Wednesday           16:00
# 18                               Tuesday, August 15th           13:00
# 19                                Wednesday to Friday
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                                NaN             NaN
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31                next Tuesday or Wednesday afternoon
# 32                                              Error           Error
# 33                                              today           15:00
# 34                                      this Saturday           10:00
# 35                                          next week
# 36                                                NaN             NaN
# 37                                                NaN             NaN
# 38                                                NaN             NaN
# 39                                                NaN             NaN
# 40                               Thursday, March 14th           14:00
# 41                                Tuesday, March 12th           10:30
# 42                                  this week or next
# 43                                  today till Friday           15:00
# 44                                           May 24th           13:30
# 45                                                NaN             NaN
# 46                                                NaN             NaN
# 47                                                NaN             NaN
# 48                                                NaN             NaN
# 49                                                NaN             NaN
#
#    meet_end_time                                 reason_for_meeting
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 9            NaN                                                NaN
# 10         10:30  Discuss Morrison campaign insights and messagi...
# 11         14:00                    Denver warehouse optimization\n
# 12         11:45  Discuss digital transformation progress and mi...
# 13                              Barcelona client contract expertise
# 14         09:30  Discuss potential synergies between our companies
# 15         10:00              Design sync for mobile app redesign\n
# 16                       Discuss logistics partnership requirements
# 17         10:00   Discuss potential collaboration on a documentary
# 18         14:30  Q4 strategic initiatives and Stellar Technolog...
# 19                               Gamify employee onboarding process
# 20           NaN                                                NaN
# 21           NaN                                                NaN
# 22           NaN                                                NaN
# 23           NaN                                                NaN
# 24           NaN                                                NaN
# 25           NaN                                                NaN
# 26           NaN                                                NaN
# 27           NaN                                                NaN
# 28           NaN                                                NaN
# 29           NaN                                                NaN
# 30           NaN                                                NaN
# 31                                  Discuss Q3 marketing strategy\n
# 32         Error                                              Error
# 33                                   Discuss the client situation\n
# 34                                   Reconnaissance of new pastries
# 35                Discuss dissertation proposal on sustainable u...
# 36           NaN                                                NaN
# 37           NaN                                                NaN
# 38           NaN                                                NaN
# 39           NaN                                                NaN
# 40         15:00           Interview for Marketing Manager position
# 41         12:00                       Software Developer interview
# 42                    Phone screen for Data Science Intern position
# 43         16:00  Initial technical interview for Data Scientist...
# 44                              Interview with Dr. James Shanahan\n
# 45           NaN                                                NaN
# 46           NaN                                                NaN
# 47           NaN                                                NaN
# 48           NaN                                                NaN
# 49           NaN                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt5, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Patricia Gonzalez' '' '' '' ''
#  'Discuss logistics partnership requirements']
# ['Maya' '' '' '' '' 'Discuss documentary collaboration']
# ['Alex' '' '' '' '' 'Catch up and discuss startup updates']
# ['Kahlil John Somera' '' '' '' '' 'Phone screen for internship']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False                       Error
# 17       False         True         False                       Error
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                       Error
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                       Error
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                meeting_requested_date meet_start_time  \
# 0                                                 NaN             NaN
# 1                                                 NaN             NaN
# 2                                                 NaN             NaN
# 3                                                 NaN             NaN
# 4                                                 NaN             NaN
# 5                                                 NaN             NaN
# 6                                                 NaN             NaN
# 7                                                 NaN             NaN
# 8                                                 NaN             NaN
# 9                                                 NaN             NaN
# 10                           Tuesday through Thursday
# 11                               tomorrow (Wednesday)           14:00
# 12  Friday, August 8th at 11 AM EST or Monday, Aug...
# 13
# 14                     sometime in the next two weeks
# 15                                      this Thursday           09:00
# 16                                              Error           Error
# 17                                              Error           Error
# 18                               Tuesday, August 15th           13:00
# 19
# 20                                                NaN             NaN
# 21                                                NaN             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                                NaN             NaN
# 27                                                NaN             NaN
# 28                                                NaN             NaN
# 29                                                NaN             NaN
# 30                                                NaN             NaN
# 31                next Tuesday or Wednesday afternoon
# 32                                              Error           Error
# 33                                              today           15:00
# 34                                      this Saturday           10:00
# 35                                          next week
# 36                                                NaN             NaN
# 37                                                NaN             NaN
# 38                                                NaN             NaN
# 39                                                NaN             NaN
# 40                               Thursday, March 14th           14:00
# 41                                Tuesday, March 12th           10:30
# 42                                              Error           Error
# 43                                  today till Friday
# 44                                           May 24th           13:30
# 45                                                NaN             NaN
# 46                                                NaN             NaN
# 47                                                NaN             NaN
# 48                                                NaN             NaN
# 49                                                NaN             NaN
#
#    meet_end_time                                 reason_for_meeting
# 0            NaN                                                NaN
# 1            NaN                                                NaN
# 2            NaN                                                NaN
# 3            NaN                                                NaN
# 4            NaN                                                NaN
# 5            NaN                                                NaN
# 6            NaN                                                NaN
# 7            NaN                                                NaN
# 8            NaN                                                NaN
# 9            NaN                                                NaN
# 10                               Discuss Morrison campaign insights
# 11         14:30                 Denver warehouse optimization idea
# 12                          Discuss digital transformation progress
# 13         18:00                  Discuss Barcelona client contract
# 14                Discuss potential synergies and predictive mod...
# 15         10:00              Review mobile app redesign wireframes
# 16         Error                                              Error
# 17         Error                                              Error
# 18         14:30     Discuss Q4 initiatives and Stellar acquisition
# 19                            Gamifying employee onboarding process
# 20           NaN                                                NaN
# 21           NaN                                                NaN
# 22           NaN                                                NaN
# 23           NaN                                                NaN
# 24           NaN                                                NaN
# 25           NaN                                                NaN
# 26           NaN                                                NaN
# 27           NaN                                                NaN
# 28           NaN                                                NaN
# 29           NaN                                                NaN
# 30           NaN                                                NaN
# 31                                    Discuss Q3 marketing strategy
# 32         Error                                              Error
# 33         15:00                       Discuss the client situation
# 34         11:00                     Reconnaissance on new pastries
# 35                                    Discuss dissertation proposal
# 36           NaN                                                NaN
# 37           NaN                                                NaN
# 38           NaN                                                NaN
# 39           NaN                                                NaN
# 40         15:00                        Marketing Manager interview
# 41         12:00          Interview for Software Developer position
# 42         Error                                              Error
# 43                              Technical interview and online test
# 44         14:30                  Interview with Dr. James Shanahan
# 45           NaN                                                NaN
# 46           NaN                                                NaN
# 47           NaN                                                NaN
# 48           NaN                                                NaN
# 49           NaN                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt5, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
# ----> 3     data_df
#       4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt5, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[35], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['request_sent_by','meeting_requested_date', 'meet_start_time', 'meet_end_time', 'reason_for_meeting']] = (
#       3     data_df
# ----> 4     .apply(lambda row: meet_information_extraction(row, info_extract_prompt5, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[23], line 55, in meet_information_extraction(row, prompt_msg, model, token, examples)
#      53 def meet_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_MEET']) == True:
# ---> 55         result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
#      56         if(len(result) != 5):
#      57             print(result)
#
# Cell In[23], line 49, in extract_MEET_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %%
email4 = """Interview Invitation – Data Scientist Role

Hi Priya,

We’re pleased to inform you that you have successfully cleared the assessment for the Data Scientist position at Quantum Analytics. Our team was impressed with your performance and would like to proceed with the next stage of the hiring process.

We would like to schedule your interview on either Tuesday, August 12th or Thursday, August 14th, between 10:00 AM and 2:00 PM. Please let us know your preferred date and time, and we will confirm the slot accordingly.

The interview will be conducted virtually via Microsoft Teams, and further details will be shared once your schedule is confirmed.

Looking forward to your response.

Best regards,
Ananya Kapoor
Recruitment Coordinator
Quantum Analytics Pvt. Ltd.
ananya.kapoor@quantumanalytics.com
+1 (628) 555-4173"""


extract_MEET_info(model2, token, info_extract_prompt5, email4)
# Out:
# array(['Quantum Analytics Pvt. Ltd.',
#        'Tuesday, August 12th or Thursday, August 14th', '', '',
#        'Interview for Data Scientist role'], dtype='<U45')
