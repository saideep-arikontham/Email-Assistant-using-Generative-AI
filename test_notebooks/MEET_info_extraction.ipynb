# %% [markdown]
# # Testing prompts for Classifying emails

# %% [markdown]
# ## Importing libraries

# %%
import os
import numpy as np
import requests
from dotenv import load_dotenv
from langsmith import traceable
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    accuracy_score, confusion_matrix, hamming_loss
)
import re

import warnings
warnings.filterwarnings("ignore")

### Getting Path of current file
import os
import sys
from pathlib import Path

path = Path(os.path.dirname(os.getcwd()))
path = str(path)
print(path)
sys.path.insert(1, path)
# Out:
# /Users/saideepbunny/Projects/Email-Assistant-using-Generative-AI

# %% [markdown]
# ## Setting API keys

# %%
load_dotenv(dotenv_path=f"{path}/config/nvidia_token.env")

model1 = "google/gemma-3n-e4b-it"
model2 = "mistralai/mistral-nemotron"
model3 = "openai/gpt-oss-120b"

token = os.getenv("NVIDIA_API_KEY")

# %% [markdown]
# ## Classification function

# %%
def classify_email(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Classify emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Cleaned classification result (only capital letters).
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{{email_content}}\n\n{prompt_msg}"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})

    # Extract only capital letters (JOB, MEET, OTHER)
    clean_result = re.sub(r'[^A-Za-z,]+', '', result)
    final_result = clean_result.split(",")
    return np.array(final_result)

# %% [markdown]
# ## Information extraction function

# %%
def extract_MEET_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{{email_content}}\n\n{prompt_msg}"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.split("|"))


def meet_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_MEET']) == True:
        result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
        if(len(result) != 6):
            print(result)
            return np.array(["Error"] * 6)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan, np.nan, np.nan, np.nan])

# %%
df = pd.read_excel(f"{path}/data/email_classification_annotated_data.xlsx", sheet_name="updated_annotated_data")
df
# Out:
#                                                 email    JOB   MEET  OTHER
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False

# %% [markdown]
# ## Email Classification

# %%
prompt = """You are an expert email class identification system. Your task is to analyze the provided email and identify if the email falls it each category or not. Your response must be **only** the True/False for each category without any additional text or metadata.

### **Categories**

**1. JOB**
Identify an email as `JOB` if it concerns the status of a specific job application. Recipient of the mail will be informed about the status of their application. This includes notifications that a candidate has:
*   Successfully applied/in the process of applying for a job (application confirmation).
*   Been shortlisted for a position.
*   Been invited to an interview or assessment.
*   Been rejected for a position.
*   Job recommendations or suggestions or ads from job boards, recruiters, companies, etc., do not classify as JOB.

**2. MEET**
Identify an email as `MEET` if the sender is requesting to schedule a meeting, virtual or in-person.
*   Can be a virtual meeting via Zoom, Google Meet, Teams, Video call, etc.
*   Can be an in-person meeting at a specific location.
*   Can be an invitation to job interviews, assessments as well.
*   Cannot be classified as MEET unless it is mentioned explicitly in the email. Future steps of a process or a job application having a meeting do not classify as MEET.

**3. OTHER**
Identify an email as `OTHER` only if it does not fit into the `JOB` or `MEET` categories. This includes, but is not limited to:
*   General job-related discussions that are not about application status (e.g., networking, asking about a role, advertisements, job suggestions or requesting for an interview).
*   Newsletters, marketing emails, personal correspondence, etc.

**Important Rules:**
*   An email cannot be identified as any other class if it classifies as OTHER.
*   An email can be identified as either JOB or either MEET or both JOB and MEET.
*   Possible combinations of classes for email are:
    *   JOB, MEET
    *   JOB
    *   MEET
    *   OTHER

### **Output Format**

Your answer must be three True or False values, one for each JOB, MEET and OTHER in this exact order:
<is a JOB>, <is a MEET>, <is OTHER>"""

# %%
data_df = df.copy()
data_df[['mistral_JOB', 'mistral_MEET', 'mistral_OTHER']] = (
    data_df['email']
    .apply(lambda x: classify_email(model2, token, prompt, x))
    .apply(pd.Series)  # convert array to 3 separate columns
)

# %%
data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER
# 0         True        False         False
# 1         True        False         False
# 2         True        False         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False

# %% [markdown]
# ## Information extraction

# %% [markdown]
# ### Prompt-1 test

# %%
info_extract_prompt1 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Meet start time — start time of the meeting if specified in the email.
3. Meet end time — end time of the meeting if specified in the email.
4. Total duration — Total duration of the meeting if specified in the email.
5. Meeting requested date - The date when the meeting was requested/ scheduled if specified in the mail.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 6 values separated by a pipe (|).

### Output format:
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>

Return the extracted information in the format above, with each detail separated by a pipe, without any additional text or metadata. If any detail is not present in the email, return an empty string for that detail (e.g., if the meet start time, end time and total duration is not mentioned, return <request_sent_by>||||<meeting_requested_date>|<reason_for_meeting>."""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Agent Jones' '' '10 AM' '' '' 'this Saturday'
#  'reconnaissance of new pastries']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                       Error
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#       meet_start_time    meet_end_time total_duration  \
# 0                 NaN              NaN            NaN
# 1                 NaN              NaN            NaN
# 2                 NaN              NaN            NaN
# 3                 NaN              NaN            NaN
# 4                 NaN              NaN            NaN
# 5                 NaN              NaN            NaN
# 6                 NaN              NaN            NaN
# 7                 NaN              NaN            NaN
# 8                 NaN              NaN            NaN
# 9                 NaN              NaN            NaN
# 10                                         30 minutes
# 11           2 PM PST
# 12          11 AM EST         3 PM EST     45 minutes
# 13                                         20 minutes
# 14                                         30 minutes
# 15           9 AM EST        10 AM EST         1 hour
# 16                                          45-minute
# 17
# 18           1 PM EST      2:30 PM EST     90 minutes
# 19                                         25 minutes
# 20                NaN              NaN            NaN
# 21                NaN              NaN            NaN
# 22                NaN              NaN            NaN
# 23                NaN              NaN            NaN
# 24                NaN              NaN            NaN
# 25                NaN              NaN            NaN
# 26                NaN              NaN            NaN
# 27                NaN              NaN            NaN
# 28                NaN              NaN            NaN
# 29                NaN              NaN            NaN
# 30                NaN              NaN            NaN
# 31
# 32
# 33               3 PM
# 34              Error            Error          Error
# 35                                         30 minutes
# 36                NaN              NaN            NaN
# 37                NaN              NaN            NaN
# 38                NaN              NaN            NaN
# 39                NaN              NaN            NaN
# 40        2:00 PM EST                      60 minutes
# 41           10:30 AM         12:00 PM     90 minutes
# 42  <meet_start_time>  <meet_end_time>  30-45 minutes
# 43
# 44        1:30 PM EST
# 45                NaN              NaN            NaN
# 46                NaN              NaN            NaN
# 47                NaN              NaN            NaN
# 48                NaN              NaN            NaN
# 49                NaN              NaN            NaN
#
#                    meeting_requested_date  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                              next week
# 11                              Wednesday
# 12                     Friday, August 8th
# 13
# 14
# 15                               Thursday
# 16
# 17
# 18                   Tuesday, August 15th
# 19  Wednesday afternoon or Friday morning
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31    next Tuesday or Wednesday afternoon
# 32                              this week
# 33                                  today
# 34                                  Error
# 35                              next week
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                   Thursday, March 14th
# 41                    Tuesday, March 12th
# 42               <meeting_requested_date>
# 43
# 44                               May 24th
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
# 49                                    NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10      Review Morrison campaign focus group insights
# 11                 Denver warehouse optimization idea
# 12            discuss digital transformation progress
# 13         Barcelona client contract tricky situation
# 14              Potential synergies between companies
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17            Discuss documentary on urban beekeeping
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19      Discuss gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      Discuss Q3 marketing strategy
# 32               Catch up and discuss startup updates
# 33                        client situation discussion
# 34                                              Error
# 35  discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42                     Discuss internship opportunity
# 43    Grad Coop interview for Data Scientist/Engineer
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                       Error
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#    meet_start_time meet_end_time            total_duration  \
# 0              NaN           NaN                       NaN
# 1              NaN           NaN                       NaN
# 2              NaN           NaN                       NaN
# 3              NaN           NaN                       NaN
# 4              NaN           NaN                       NaN
# 5              NaN           NaN                       NaN
# 6              NaN           NaN                       NaN
# 7              NaN           NaN                       NaN
# 8              NaN           NaN                       NaN
# 9              NaN           NaN                       NaN
# 10                                               30-minute
# 11        2 PM PST
# 12           Error         Error                     Error
# 13                                              20 minutes
# 14                                               30-minute
# 15        9 AM EST                           about an hour
# 16                                               45-minute
# 17
# 18        1 PM EST                        about 90 minutes
# 19                                               25-minute
# 20             NaN           NaN                       NaN
# 21             NaN           NaN                       NaN
# 22             NaN           NaN                       NaN
# 23             NaN           NaN                       NaN
# 24             NaN           NaN                       NaN
# 25             NaN           NaN                       NaN
# 26             NaN           NaN                       NaN
# 27             NaN           NaN                       NaN
# 28             NaN           NaN                       NaN
# 29             NaN           NaN                       NaN
# 30             NaN           NaN                       NaN
# 31
# 32
# 33            3 PM
# 34           10 AM
# 35                                approximately 30 minutes
# 36             NaN           NaN                       NaN
# 37             NaN           NaN                       NaN
# 38             NaN           NaN                       NaN
# 39             NaN           NaN                       NaN
# 40     2:00 PM EST                approximately 60 minutes
# 41        10:30 AM      12:00 PM                90 minutes
# 42                                            30-45 minute
# 43                                                  1 hour
# 44     1:30 PM EST
# 45             NaN           NaN                       NaN
# 46             NaN           NaN                       NaN
# 47             NaN           NaN                       NaN
# 48             NaN           NaN                       NaN
# 49             NaN           NaN                       NaN
#
#                  meeting_requested_date  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10
# 11                 tomorrow (Wednesday)
# 12                                Error
# 13
# 14
# 15                        this Thursday
# 16
# 17
# 18                 Tuesday, August 15th
# 19
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# 30                                  NaN
# 31  next Tuesday or Wednesday afternoon
# 32
# 33                                today
# 34                        this Saturday
# 35
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                 Thursday, March 14th
# 41                  Tuesday, March 12th
# 42
# 43
# 44                             May 24th
# 45                                  NaN
# 46                                  NaN
# 47                                  NaN
# 48                                  NaN
# 49                                  NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Discuss preliminary data insights and adjust m...
# 11     Discuss idea on Denver warehouse optimization.
# 12                                              Error
# 13  Discuss Barcelona client contract issue needin...
# 14  Discuss potential synergies and learn about Br...
# 15             Review mobile app redesign wireframes.
# 16  Discuss logistics requirements, temperature-se...
# 17  Discuss potential visual collaboration on urba...
# 18  Review Q4 strategic initiatives and due dilige...
# 19  Discuss gamified employee onboarding ideas and...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Discuss Q3 marketing strategy and product laun...
# 32            to catch up and discuss startup updates
# 33                    Discuss urgent client situation
# 34  Investigate new pastries for immediate reconna...
# 35  Discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Interview for Marketing Manager position at Ne...
# 41          Interview for Software Developer position
# 42  Schedule phone screen to discuss educational s...
# 43  Initial round technical interview for Grad Coo...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %% [markdown]
# ### Prompt-2 test

# %%
info_extract_prompt2 = """
You are an information extraction assistant.  
You will receive the full text of an email containing a meeting request.  
This may be for a virtual meeting, in-person meeting, or job interview.

Your task:  
Read the email carefully and extract the following details exactly as they appear in the email.  
If a detail is not mentioned, return an empty string for that field.

Fields to extract (in order):  
1. Request sent by – Name of the person or organization requesting the meeting.  
2. Meet start time – Start time of the meeting.  
3. Meet end time – End time of the meeting.  
4. Total duration – Total duration of the meeting.  
5. Meeting requested date – Date the meeting is scheduled/requested.  
6. Reason for meeting – Summarize in ≤15 words.

**Output format:**  
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>  

**Rules:**  
- There must be exactly 6 values separated by 5 pipe (|) characters.
- Use exactly the wording from the email for all fields except “Reason for meeting,” which should be a concise summary.  
- Do not add extra words, punctuation, or formatting outside the specified structure.  
- Maintain the order of fields exactly as shown.  
- If a value is missing, leave it blank but keep the pipe separators.  
- The output must be a single line only.

Example:  
If only the requester's name, requested date, and reason are present, return:  
John Smith||||2024-08-15|Discuss project timeline
"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['Michael Rodriguez' '' '' '30 minutes' '' ''
#  'Discuss potential synergies between companies']
# ['Patricia Gonzalez' '' '' '45 minutes' '' ''
#  'Discuss logistics partnership requirements']
# ['Agent Jones' '' '10 AM' '' '' 'Saturday'
#  'Reconnaissance on new pastries']
# ['Kahlil John Somera' '' '' '30-45 minutes' '' ''
#  'Phone interview for internship']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False                       Error
# 15       False         True         False                        Alex
# 16       False         True         False                       Error
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                       Error
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False                       Error
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#    meet_start_time meet_end_time total_duration  \
# 0              NaN           NaN            NaN
# 1              NaN           NaN            NaN
# 2              NaN           NaN            NaN
# 3              NaN           NaN            NaN
# 4              NaN           NaN            NaN
# 5              NaN           NaN            NaN
# 6              NaN           NaN            NaN
# 7              NaN           NaN            NaN
# 8              NaN           NaN            NaN
# 9              NaN           NaN            NaN
# 10
# 11        2 PM PST
# 12       11 AM EST  12:45 PM EST     45 minutes
# 13                          6 PM
# 14           Error         Error          Error
# 15        9 AM EST     10 AM EST         1 hour
# 16           Error         Error          Error
# 17        4 PM PST      5 PM PST         1 hour
# 18        1 PM EST                   90 minutes
# 19                                   25 minutes
# 20             NaN           NaN            NaN
# 21             NaN           NaN            NaN
# 22             NaN           NaN            NaN
# 23             NaN           NaN            NaN
# 24             NaN           NaN            NaN
# 25             NaN           NaN            NaN
# 26             NaN           NaN            NaN
# 27             NaN           NaN            NaN
# 28             NaN           NaN            NaN
# 29             NaN           NaN            NaN
# 30             NaN           NaN            NaN
# 31
# 32
# 33            3 PM
# 34           Error         Error          Error
# 35                                   30 minutes
# 36             NaN           NaN            NaN
# 37             NaN           NaN            NaN
# 38             NaN           NaN            NaN
# 39             NaN           NaN            NaN
# 40     2:00 PM EST                   60 minutes
# 41        10:30 AM      12:00 PM     90 minutes
# 42           Error         Error          Error
# 43
# 44     1:30 PM EST
# 45             NaN           NaN            NaN
# 46             NaN           NaN            NaN
# 47             NaN           NaN            NaN
# 48             NaN           NaN            NaN
# 49             NaN           NaN            NaN
#
#                    meeting_requested_date  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                              next week
# 11                              Wednesday
# 12                     Friday, August 8th
# 13                                  today
# 14                                  Error
# 15                               Thursday
# 16                                  Error
# 17                                Tuesday
# 18                            August 15th
# 19  Wednesday afternoon or Friday morning
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# 30                                    NaN
# 31    next Tuesday or Wednesday afternoon
# 32
# 33                                  today
# 34                                  Error
# 35                              next week
# 36                                    NaN
# 37                                    NaN
# 38                                    NaN
# 39                                    NaN
# 40                             March 14th
# 41                    Tuesday, March 12th
# 42                                  Error
# 43
# 44                               May 24th
# 45                                    NaN
# 46                                    NaN
# 47                                    NaN
# 48                                    NaN
# 49                                    NaN
#
#                         reason_for_meeting
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# 5                                      NaN
# 6                                      NaN
# 7                                      NaN
# 8                                      NaN
# 9                                      NaN
# 10      Discuss Morrison campaign insights
# 11      Denver warehouse optimization idea
# 12  Review digital transformation progress
# 13         Barcelona client contract issue
# 14                                   Error
# 15   Review mobile app redesign wireframes
# 16                                   Error
# 17       Discuss documentary collaboration
# 18    Q4 initiatives & Stellar acquisition
# 19           Gamifying employee onboarding
# 20                                     NaN
# 21                                     NaN
# 22                                     NaN
# 23                                     NaN
# 24                                     NaN
# 25                                     NaN
# 26                                     NaN
# 27                                     NaN
# 28                                     NaN
# 29                                     NaN
# 30                                     NaN
# 31           Discuss Q3 marketing strategy
# 32       Catch up on startup scene updates
# 33    Discuss client situation immediately
# 34                                   Error
# 35           Discuss dissertation proposal
# 36                                     NaN
# 37                                     NaN
# 38                                     NaN
# 39                                     NaN
# 40             Marketing Manager interview
# 41            Software Developer interview
# 42                                   Error
# 43      Grad Coop interview technical test
# 44       Interview with Dr. James Shanahan
# 45                                     NaN
# 46                                     NaN
# 47                                     NaN
# 48                                     NaN
# 49                                     NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER  \
# 0         True        False         False
# 1         True        False         False
# 2         True        False         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False
#
#                                 request_sent_by meet_start_time meet_end_time  \
# 0                                           NaN             NaN           NaN
# 1                                           NaN             NaN           NaN
# 2                                           NaN             NaN           NaN
# 3                                           NaN             NaN           NaN
# 4                                           NaN             NaN           NaN
# 5                                           NaN             NaN           NaN
# 6                                           NaN             NaN           NaN
# 7                                           NaN             NaN           NaN
# 8                                           NaN             NaN           NaN
# 9                                           NaN             NaN           NaN
# 10                                        Error           Error         Error
# 11                                        Elena        2 PM PST
# 12                                   David Chen
# 13                                         Jake
# 14                            Michael Rodriguez
# 15                                         Alex        9 AM EST
# 16                            Patricia Gonzalez
# 17                                         Maya        4 PM PST
# 18                               Jonathan Mills        1 PM EST
# 19                                     Samantha
# 20                                          NaN             NaN           NaN
# 21                                          NaN             NaN           NaN
# 22                                          NaN             NaN           NaN
# 23                                          NaN             NaN           NaN
# 24                                          NaN             NaN           NaN
# 25                                          NaN             NaN           NaN
# 26                                          NaN             NaN           NaN
# 27                                          NaN             NaN           NaN
# 28                                          NaN             NaN           NaN
# 29                                          NaN             NaN           NaN
# 30                                          NaN             NaN           NaN
# 31                                   Sarah Chen
# 32                                         Alex
# 33                                     Michelle            3 PM
# 34                                  Agent Jones           10 AM
# 35                                   David Park
# 36                                          NaN             NaN           NaN
# 37                                          NaN             NaN           NaN
# 38                                          NaN             NaN           NaN
# 39                                          NaN             NaN           NaN
# 40  Human Resources Department, Nexus Solutions     2:00 PM EST
# 41                               Sarah Mitchell        10:30 AM      12:00 PM
# 42                           Kahlil John Somera
# 43                                    Rakshitha
# 44                                    Rakshitha     1:30 PM EST
# 45                                          NaN             NaN           NaN
# 46                                          NaN             NaN           NaN
# 47                                          NaN             NaN           NaN
# 48                                          NaN             NaN           NaN
# 49                                          NaN             NaN           NaN
#
#               total_duration meeting_requested_date  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                        NaN                    NaN
# 8                        NaN                    NaN
# 9                        NaN                    NaN
# 10                     Error                  Error
# 11                             tomorrow (Wednesday)
# 12  approximately 45 minutes
# 13                20 minutes
# 14                 30-minute
# 15             about an hour          this Thursday
# 16                 45-minute
# 17                                     this Tuesday
# 18          about 90 minutes   Tuesday, August 15th
# 19                 25-minute
# 20                       NaN                    NaN
# 21                       NaN                    NaN
# 22                       NaN                    NaN
# 23                       NaN                    NaN
# 24                       NaN                    NaN
# 25                       NaN                    NaN
# 26                       NaN                    NaN
# 27                       NaN                    NaN
# 28                       NaN                    NaN
# 29                       NaN                    NaN
# 30                       NaN                    NaN
# 31
# 32
# 33                                            today
# 34
# 35  approximately 30 minutes
# 36                       NaN                    NaN
# 37                       NaN                    NaN
# 38                       NaN                    NaN
# 39                       NaN                    NaN
# 40  approximately 60 minutes   Thursday, March 14th
# 41          about 90 minutes    Tuesday, March 12th
# 42
# 43                   an hour
# 44                                         May 24th
# 45                       NaN                    NaN
# 46                       NaN                    NaN
# 47                       NaN                    NaN
# 48                       NaN                    NaN
# 49                       NaN                    NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                              Error
# 11     Discuss idea for Denver warehouse optimization
# 12  Monthly review of digital transformation progr...
# 13  Discuss Barcelona client contract and need int...
# 14  Discuss synergies and Brightwave's retail pred...
# 15          Review wireframes for mobile app redesign
# 16  Discuss requirements and learn about capabilit...
# 17  Virtual coffee to discuss urban beekeeping doc...
# 18  Discuss Q4 strategic initiatives and Stellar T...
# 19  Discuss gamified employee onboarding ideas and...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Discuss Q3 marketing strategy and upcoming pro...
# 32   Discuss startup updates and catch up over coffee
# 33                    Discuss urgent client situation
# 34  Investigate new pastries requiring immediate r...
# 35  Discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40  Interview for Marketing Manager position at Ne...
# 41          Interview for Software Developer position
# 42      Phone screen for Data Science Intern position
# 43  Initial technical interview for Grad Coop Data...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_extract_prompt3 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Meet start time — start time of the meeting if specified in the email.
3. Meet end time — end time of the meeting if specified in the email.
4. Total duration — Total duration of the meeting if specified in the email.
5. Meeting requested date - The date when the meeting was requested/ scheduled if specified in the mail.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 6 values separated by a pipe (|).

### Output format:
<request_sent_by>|<meet_start_time>|<meet_end_time>|<total_duration>|<meeting_requested_date>|<reason_for_meeting>"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                     meet_start_time                    meet_end_time  \
# 0                               NaN                              NaN
# 1                               NaN                              NaN
# 2                               NaN                              NaN
# 3                               NaN                              NaN
# 4                               NaN                              NaN
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                               NaN                              NaN
# 10                        10 AM EST                         4 PM EST
# 11                         2 PM PST                               ""
# 12  Friday, August 8th at 11 AM EST  Monday, August 11th at 3 PM EST
# 13                   6 PM your time           early tomorrow morning
# 14                <meet_start_time>                  <meet_end_time>
# 15                         9 AM EST                        10 AM EST
# 16                         9 AM EST                         3 PM EST
# 17
# 18                         1 PM EST                      2:30 PM EST
# 19              Wednesday afternoon                   Friday morning
# 20                              NaN                              NaN
# 21                              NaN                              NaN
# 22                              NaN                              NaN
# 23                              NaN                              NaN
# 24                              NaN                              NaN
# 25                              NaN                              NaN
# 26                              NaN                              NaN
# 27                              NaN                              NaN
# 28                              NaN                              NaN
# 29                              NaN                              NaN
# 30                              NaN                              NaN
# 31
# 32
# 33                             3 PM                               ""
# 34                            10 AM                               ""
# 35
# 36                              NaN                              NaN
# 37                              NaN                              NaN
# 38                              NaN                              NaN
# 39                              NaN                              NaN
# 40                      2:00 PM EST                      3:00 PM EST
# 41                         10:30 AM                         12:00 PM
# 42                               ""                               ""
# 43
# 44                      1:30 PM EST                               ""
# 45                              NaN                              NaN
# 46                              NaN                              NaN
# 47                              NaN                              NaN
# 48                              NaN                              NaN
# 49                              NaN                              NaN
#
#    total_duration               meeting_requested_date  \
# 0             NaN                                  NaN
# 1             NaN                                  NaN
# 2             NaN                                  NaN
# 3             NaN                                  NaN
# 4             NaN                                  NaN
# 5             NaN                                  NaN
# 6             NaN                                  NaN
# 7             NaN                                  NaN
# 8             NaN                                  NaN
# 9             NaN                                  NaN
# 10      30-minute                            next week
# 11             ""                            Wednesday
# 12     45 minutes
# 13     20 minutes
# 14      30-minute             <meeting_requested_date>
# 15         1 hour                             Thursday
# 16      45-minute                                   ""
# 17
# 18     90 minutes                 Tuesday, August 15th
# 19      25-minute                            this week
# 20            NaN                                  NaN
# 21            NaN                                  NaN
# 22            NaN                                  NaN
# 23            NaN                                  NaN
# 24            NaN                                  NaN
# 25            NaN                                  NaN
# 26            NaN                                  NaN
# 27            NaN                                  NaN
# 28            NaN                                  NaN
# 29            NaN                                  NaN
# 30            NaN                                  NaN
# 31                 next Tuesday or Wednesday afternoon
# 32
# 33             ""                                today
# 34             ""                             Saturday
# 35     30 minutes                            next week
# 36            NaN                                  NaN
# 37            NaN                                  NaN
# 38            NaN                                  NaN
# 39            NaN                                  NaN
# 40     60 minutes                 Thursday, March 14th
# 41     90 minutes                  Tuesday, March 12th
# 42  30-45 minutes                                   ""
# 43         1 hour
# 44             ""                             May 24th
# 45            NaN                                  NaN
# 46            NaN                                  NaN
# 47            NaN                                  NaN
# 48            NaN                                  NaN
# 49            NaN                                  NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10     Discuss Morrison campaign focus group insights
# 11                 Denver warehouse optimization idea
# 12  Discuss digital transformation progress and mi...
# 13                    Barcelona client contract issue
# 14      Discuss potential synergies between companies
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17  Discuss artistic sequences for urban beekeepin...
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19      Discuss gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      Discuss Q3 marketing strategy
# 32         Catch up and discuss startup scene updates
# 33                        client situation discussion
# 34                        New pastries reconnaissance
# 35  discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42                     Discuss internship opportunity
# 43    Grad Coop interview for Data Scientist/Engineer
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'meet_start_time', 'meet_end_time', 'total_duration', 'meeting_requested_date', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ['']
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                       Error
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#         meet_start_time meet_end_time            total_duration  \
# 0                   NaN           NaN                       NaN
# 1                   NaN           NaN                       NaN
# 2                   NaN           NaN                       NaN
# 3                   NaN           NaN                       NaN
# 4                   NaN           NaN                       NaN
# 5                   NaN           NaN                       NaN
# 6                   NaN           NaN                       NaN
# 7                   NaN           NaN                       NaN
# 8                   NaN           NaN                       NaN
# 9                   NaN           NaN                       NaN
# 10                Error         Error                     Error
# 11             2 PM PST
# 12  11 AM EST; 3 PM EST                approximately 45 minutes
# 13                                                   20 minutes
# 14                                                   30 minutes
# 15             9 AM EST                           about an hour
# 16                                                    45-minute
# 17             4 PM PST
# 18             1 PM EST                              90 minutes
# 19                                                    25-minute
# 20                  NaN           NaN                       NaN
# 21                  NaN           NaN                       NaN
# 22                  NaN           NaN                       NaN
# 23                  NaN           NaN                       NaN
# 24                  NaN           NaN                       NaN
# 25                  NaN           NaN                       NaN
# 26                  NaN           NaN                       NaN
# 27                  NaN           NaN                       NaN
# 28                  NaN           NaN                       NaN
# 29                  NaN           NaN                       NaN
# 30                  NaN           NaN                       NaN
# 31
# 32
# 33                 3 PM
# 34                10 AM
# 35                                     approximately 30 minutes
# 36                  NaN           NaN                       NaN
# 37                  NaN           NaN                       NaN
# 38                  NaN           NaN                       NaN
# 39                  NaN           NaN                       NaN
# 40          2:00 PM EST                approximately 60 minutes
# 41             10:30 AM      12:00 PM                90 minutes
# 42                                                 30-45 minute
# 43                                                       1 hour
# 44          1:30 PM EST
# 45                  NaN           NaN                       NaN
# 46                  NaN           NaN                       NaN
# 47                  NaN           NaN                       NaN
# 48                  NaN           NaN                       NaN
# 49                  NaN           NaN                       NaN
#
#                      meeting_requested_date  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                    Error
# 11                     tomorrow (Wednesday)
# 12  Friday, August 8th; Monday, August 11th
# 13
# 14
# 15                            this Thursday
# 16
# 17
# 18                     Tuesday, August 15th
# 19
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# 30                                      NaN
# 31
# 32
# 33                                    today
# 34                            this Saturday
# 35
# 36                                      NaN
# 37                                      NaN
# 38                                      NaN
# 39                                      NaN
# 40                     Thursday, March 14th
# 41                      Tuesday, March 12th
# 42
# 43
# 44                                 May 24th
# 45                                      NaN
# 46                                      NaN
# 47                                      NaN
# 48                                      NaN
# 49                                      NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                              Error
# 11          Idea about Denver warehouse optimization.
# 12  Monthly review meeting to discuss digital tran...
# 13  Discuss Barcelona client contract issue needin...
# 14  Discuss potential synergies and Brightwave's p...
# 15          Review wireframes for mobile app redesign
# 16  Discuss logistics requirements, capabilities f...
# 17  Discuss visual style for urban beekeeping docu...
# 18  Discuss Q4 initiatives and Stellar Technologie...
# 19  Discuss gamifying employee onboarding ideas an...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Discuss Q3 marketing strategy and upcoming pro...
# 32              Catch up and discuss startup updates.
# 33                    Discuss urgent client situation
# 34     New pastries require immediate reconnaissance.
# 35  Discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40           Interview for Marketing Manager position
# 41  Software Developer interview: technical interv...
# 42  Phone screen to discuss candidate's background...
# 43  Initial technical interview for Grad Coop Data...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
def extract_MEET_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{{email_content}}\n\n{prompt_msg}"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.strip().split("|"))


def meet_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_MEET']) == True:
        result = extract_MEET_info(model, token, prompt_msg, row['email'], examples)
        if(len(result) != 3):
            print(result)
            return np.array(["Error"] * 3)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan])

# %%
info_extract_prompt4 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a meeting request. It can be a virtual meeting, in-person meeting, audio/video call, a job interview request, etc.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Request sent by — The name of the person or body that is requesting the meeting.
2. Requested date and time - The date and time when the meeting is requested to be held. Make sure to return the exact content if specified.
6. Reason for meeting - The reason for meeting if specified in the email. Make sure to summarize the reason in no more than 15 words.

** Important Rule:**
- The output must have exactly 3 values separated by a pipe (|).

### Output format:
<request_sent_by>|<requested_date_time>|<reason_for_meeting>"""

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                   requested_date_time  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Tuesday through Thursday between 10 AM and 4 P...
# 11                              Wednesday at 2 PM PST
# 12  Friday, August 8th at 11 AM EST or Monday, Aug...
# 13         today until 6 PM or early tomorrow morning
# 14                              in the next two weeks
# 15                               Thursday at 9 AM EST
# 16                      9 AM and 3 PM EST on weekdays
# 17      Tuesday at 4 PM PST or Wednesday at 10 AM PST
# 18                   Tuesday, August 15th at 1 PM EST
# 19              Wednesday afternoon or Friday morning
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                next Tuesday or Wednesday afternoon
# 32                                          this week
# 33                                         3 PM today
# 34                             this Saturday at 10 AM
# 35                                          next week
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                Thursday, March 14th at 2:00 PM EST
# 41           Tuesday, March 12th, 10:30 AM - 12:00 PM
# 42                                  this week or next
# 43   today till Friday anytime between 3 PM -6 PM EST
# 44                            May 24th at 1:30 PM EST
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Review preliminary data from Morrison campaign...
# 11               Denver warehouse optimization idea\n
# 12  discuss progress on digital transformation ini...
# 13  tricky situation involving the Barcelona clien...
# 14  continue conversation about potential synergie...
# 15  Design sync for mobile app redesign wireframes...
# 16  Discuss logistics partnership for East Coast d...
# 17  Discuss potential collaboration on visual styl...
# 18  Discuss Q4 strategic initiatives and potential...
# 19  Discuss gamifying the employee onboarding proc...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  discuss our Q3 marketing strategy, upcoming pr...
# 32  catch up, share startup updates, and hear abou...
# 33         discuss the client situation immediately\n
# 34                   reconnaissance of new pastries\n
# 35  discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40           Interview for Marketing Manager position
# 41            Software Developer position interview\n
# 42  phone screen for Data Science Intern position ...
# 43  initial round of interviews for Grad Coop for ...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                   requested_date_time  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Tuesday through Thursday, anytime between 10 A...
# 11                              Wednesday at 2 PM PST
# 12  Friday, August 8th at 11 AM EST or Monday, Aug...
# 13                    today or early tomorrow morning
# 14  weekday mornings before 11 AM PST or after 2 P...
# 15                               Thursday at 9 AM EST
# 16                      9 AM and 3 PM EST on weekdays
# 17      Tuesday at 4 PM PST or Wednesday at 10 AM PST
# 18                   Tuesday, August 15th at 1 PM EST
# 19              Wednesday afternoon or Friday morning
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                next Tuesday or Wednesday afternoon
# 32
# 33                                         3 PM today
# 34                             this Saturday at 10 AM
# 35
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                Thursday, March 14th at 2:00 PM EST
# 41           Tuesday, March 12th, 10:30 AM - 12:00 PM
# 42                                                 ""
# 43  anytime between 3 PM -6 PM EST from today till...
# 44                            May 24th at 1:30 PM EST
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Discuss Morrison campaign focus group insights...
# 11                 Denver warehouse optimization idea
# 12  Discuss digital transformation progress and mi...
# 13                    Barcelona client contract issue
# 14      Discuss potential synergies between companies
# 15              Review mobile app redesign wireframes
# 16         Discuss logistics partnership requirements
# 17            Discuss documentary on urban beekeeping
# 18  Q4 strategic initiatives and Stellar Technolog...
# 19      Discuss gamifying employee onboarding process
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                      discuss Q3 marketing strategy
# 32               exciting updates about startup scene
# 33                    Discuss urgent client situation
# 34                     reconnaissance of new pastries
# 35  discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                        Marketing Manager interview
# 41          Interview for Software Developer position
# 42          Discuss internship opportunity and skills
# 43    Grad Coop interview for Data Scientist/Engineer
# 44                  Interview with Dr. James Shanahan
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
info_data_df = data_df.copy()
info_data_df[['request_sent_by', 'requested_date_time', 'reason_for_meeting']] = (
    data_df
    .apply(lambda row: meet_information_extraction(row, info_extract_prompt4, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER             request_sent_by  \
# 0         True        False         False                         NaN
# 1         True        False         False                         NaN
# 2         True        False         False                         NaN
# 3         True        False         False                         NaN
# 4         True        False         False                         NaN
# 5         True        False         False                         NaN
# 6         True        False         False                         NaN
# 7         True        False         False                         NaN
# 8         True        False         False                         NaN
# 9         True        False         False                         NaN
# 10       False         True         False                      Marcus
# 11       False         True         False                       Elena
# 12       False         True         False                  David Chen
# 13       False         True         False                        Jake
# 14       False         True         False           Michael Rodriguez
# 15       False         True         False                        Alex
# 16       False         True         False           Patricia Gonzalez
# 17       False         True         False                        Maya
# 18       False         True         False              Jonathan Mills
# 19       False         True         False                    Samantha
# 20       False        False          True                         NaN
# 21       False        False          True                         NaN
# 22       False        False          True                         NaN
# 23       False        False          True                         NaN
# 24       False        False          True                         NaN
# 25       False        False          True                         NaN
# 26       False        False          True                         NaN
# 27       False        False          True                         NaN
# 28        True        False         False                         NaN
# 29       False        False          True                         NaN
# 30       False        False          True                         NaN
# 31       False         True         False                  Sarah Chen
# 32       False         True         False                        Alex
# 33       False         True         False                    Michelle
# 34       False         True         False                 Agent Jones
# 35       False         True         False                  David Park
# 36       False        False          True                         NaN
# 37       False        False          True                         NaN
# 38       False        False          True                         NaN
# 39       False        False          True                         NaN
# 40        True         True         False  Human Resources Department
# 41        True         True         False              Sarah Mitchell
# 42        True         True         False          Kahlil John Somera
# 43        True         True         False                   Rakshitha
# 44        True         True         False                   Rakshitha
# 45        True        False         False                         NaN
# 46        True        False         False                         NaN
# 47        True        False         False                         NaN
# 48        True        False         False                         NaN
# 49        True        False         False                         NaN
#
#                                   requested_date_time  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Tuesday through Thursday work best for me, any...
# 11                   tomorrow (Wednesday) at 2 PM PST
# 12  Friday, August 8th at 11 AM EST; Monday, Augus...
# 13  today until 6 PM your time, or early tomorrow ...
# 14
# 15                          this Thursday at 9 AM EST
# 16
# 17  this Tuesday at 4 PM PST or Wednesday at 10 AM...
# 18                   Tuesday, August 15th at 1 PM EST
# 19              Wednesday afternoon or Friday morning
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                next Tuesday or Wednesday afternoon
# 32
# 33                                         3 PM today
# 34                             this Saturday at 10 AM
# 35
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                Thursday, March 14th at 2:00 PM EST
# 41            Tuesday, March 12th 10:30 AM - 12:00 PM
# 42
# 43   today till Friday anytime between 3 PM -6 PM EST
# 44                            May 24th at 1:30 PM EST
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                    reason_for_meeting
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Discuss Morrison campaign focus group findings...
# 11          Idea about Denver warehouse optimization.
# 12  Monthly review meeting to discuss progress on ...
# 13  Advice on a tricky Barcelona client contract r...
# 14  Discuss potential synergies and learn about Br...
# 15             Review mobile app redesign wireframes.
# 16  Discuss logistics requirements, temperature-se...
# 17  Discuss urban beekeeping documentary and visua...
# 18  Discuss Q4 initiatives and Stellar Technologie...
# 19  Discuss gamified employee onboarding ideas and...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31  Discuss Q3 marketing strategy and upcoming pro...
# 32              Catch up and discuss startup updates.
# 33              Discuss client situation immediately.
# 34     New pastries require immediate reconnaissance.
# 35  Discuss dissertation proposal on sustainable u...
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40           Interview for Marketing Manager position
# 41      Interview for the Software Developer position
# 42  Phone screen to discuss your background and Ve...
# 43  Initial technical interview for Grad Coop Data...
# 44  Interview with Dr. James (Jimi) Shanahan, Dire...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
