# %% [markdown]
# # Testing prompts for Classifying emails

# %% [markdown]
# ## Importing libraries

# %%
import os
import numpy as np
import requests
from dotenv import load_dotenv
from langsmith import traceable
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    precision_score, recall_score, f1_score,
    accuracy_score, confusion_matrix, hamming_loss
)
import re

import warnings
warnings.filterwarnings("ignore")

### Getting Path of current file
import os
import sys
from pathlib import Path

path = Path(os.path.dirname(os.getcwd()))
path = str(path)
print(path)
sys.path.insert(1, path)
# Out:
# /Users/saideepbunny/Projects/Email-Assistant-using-Generative-AI

# %% [markdown]
# ## Setting API keys

# %%
load_dotenv(dotenv_path=f"{path}/config/nvidia_token.env")

model1 = "google/gemma-3n-e4b-it"
model2 = "mistralai/mistral-nemotron"
model3 = "moonshotai/kimi-k2-instruct"

token = os.getenv("NVIDIA_API_KEY")

# %% [markdown]
# ## Classification function

# %%
def classify_email(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Classify emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Cleaned classification result (only capital letters).
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{{email_content}}\n\n{prompt_msg}"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.2,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})

    # Extract only capital letters (JOB, MEET, OTHER)
    clean_result = re.sub(r'[^A-Za-z,]+', '', result)
    final_result = clean_result.split(",")
    return np.array(final_result)

# %% [markdown]
# ## Information extraction function

# %%
def extract_JOB_info(model, token, prompt_msg, email_content: str, examples: list = None):
    """
    Extract information from JOB emails using an NVIDIA LLM with optional few-shot examples.

    Args:
        model (str): NVIDIA LLM model name.
        token (str): API key for NVIDIA LLM.
        prompt_msg (str): Classification instruction message.
        email_content (str): Email text to classify.
        examples (list, optional): Few-shot examples in the form 
                                   [{"email": "example email", "label": "JOB"}, ...]

    Returns:
        str: Extracted information result.
    """

    # Build few-shot messages
    messages = []

    # Add few-shot examples if provided
    if examples:
        for ex in examples:
            messages.append(("user", ex["email"]))
            messages.append(("assistant", ex["label"]))

    # Add the actual email to classify
    messages.append((
        "user",
        f"""{prompt_msg}\n\n EMAIL TO ANALYZE: {{email_content}} \n\n PIPE-DELIMITED OUTPUT:"""
    ))

    # Create prompt template
    prompt = ChatPromptTemplate.from_messages(messages)

    # Use the NVIDIA LLM via LangChain
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.0,
        top_p=1.0,
        max_tokens=4096,
        streaming=False
    )

    # Define chain
    chain = prompt | llm | StrOutputParser()

    # Run it
    result = chain.invoke({"email_content": email_content})
    return np.array(result.split("|"))


def job_information_extraction(row, prompt_msg, model, token, examples=None):
    if eval(row['mistral_JOB']) == True:
        result = extract_JOB_info(model, token, prompt_msg, row['email'], examples)
        return result

    else:
        return np.array([np.nan, np.nan, np.nan, np.nan])

# %%
df = pd.read_excel(f"{path}/data/email_classification_annotated_data.xlsx", sheet_name="updated_annotated_data")
df
# Out:
#                                                 email    JOB   MEET  OTHER
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False

# %% [markdown]
# ## Email Classification

# %%
prompt = """You are an expert email class identification system. Your task is to analyze the provided email and identify if the email falls it each category or not. Your response must be **only** the True/False for each category without any additional text or metadata.

### **Categories**

**1. JOB**
Identify an email as `JOB` if it concerns the status of a specific job application. Recipient of the mail will be informed about the status of their application. This includes notifications that a candidate has:
*   Successfully applied/in the process of applying for a job (application confirmation).
*   Been shortlisted for a position.
*   Been invited to an interview or assessment.
*   Been rejected for a position.
*   Job recommendations or suggestions or ads from job boards, recruiters, companies, etc., do not classify as JOB.

**2. MEET**
Identify an email as `MEET` if the sender is requesting to schedule a meeting, virtual or in-person.
*   Can be a virtual meeting via Zoom, Google Meet, Teams, Video call, etc.
*   Can be an in-person meeting at a specific location.
*   Can be an invitation to job interviews, assessments as well.
*   Cannot be classified as MEET unless it is mentioned explicitly in the email. Future steps of a process or a job application having a meeting do not classify as MEET.

**3. OTHER**
Identify an email as `OTHER` only if it does not fit into the `JOB` or `MEET` categories. This includes, but is not limited to:
*   General job-related discussions that are not about application status (e.g., networking, asking about a role, advertisements, job suggestions or requesting for an interview).
*   Newsletters, marketing emails, personal correspondence, etc.

**Important Rules:**
*   An email cannot be identified as any other class if it classifies as OTHER.
*   An email can be identified as either JOB or either MEET or both JOB and MEET.
*   Possible combinations of classes for email are:
    *   JOB, MEET
    *   JOB
    *   MEET
    *   OTHER

### **Output Format**

Your answer must be three True or False values, one for each JOB, MEET and OTHER in this exact order:
<is a JOB>, <is a MEET>, <is OTHER>"""

# %%
data_df = df.copy()
data_df[['mistral_JOB', 'mistral_MEET', 'mistral_OTHER']] = (
    data_df['email']
    .apply(lambda x: classify_email(model2, token, prompt, x))
    .apply(pd.Series)  # convert array to 3 separate columns
)

# %%
data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER
# 0         True        False         False
# 1         True        False         False
# 2         True         True         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False

# %% [markdown]
# ## Information extraction

# %% [markdown]
# ### Prompt-1 test

# %%
info_extract_prompt1 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a candidate’s job application status.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Company Name — The company or organization sending the email.
2. Job Role — The job title or role mentioned in the email.
3. Job ID — The job requisition ID, reference number, or posting number mentioned.
4. Application Status — One of the following categories that best describes the current stage:
   - application incomplete : emails that mention application is not complete
   - applied : emails that convey that the candidate has applied for the job
   - assessment: emails that mention about an assessment or evaluation process after being shortlisted.
   - interview: emails that mention about an interview process. Contains text talking about the interview process, schedule, format, etc. Do not base the decision based on the sender's email.
   - job offered: emails that mention that the candidate has been offered a job.
   - rejected: emails that mention that the candidate has been rejected for the job.
   - withdrawn: emails that mention that the candidate has withdrawn their application.
   - other (if none of the above applies): if the email does not fit into any of the above categories, return "other".
5. Email Sent by - The sender of the email. It can be the person, talent acquisition team, etc.

### Output format:
<company_name>|<job_role>|<job_id>|<application_status>|<sent_by>

Return the extracted information in the format above, with each detail separated by a pipe, without any additional text or metadata. If any detail is not present in the email, return an empty string for that detail (e.g., if the job ID is not mentioned, return <company_name>,<job_role>,,<application_status>,<sent_by>)."""

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt1, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER  \
# 0         True        False         False
# 1         True        False         False
# 2         True         True         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False
#
#                            company_name  \
# 0                                 iSpot
# 1                       CHS Career Site
# 2                                GoodRx
# 3                               Klaviyo
# 4                                Embark
# 5                                   AEP
# 6     Chan Zuckerberg Imaging Institute
# 7                                Astera
# 8                                Reddit
# 9                            PulsePoint
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28         Ford Talent Acquisition Team
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34                                  NaN
# 35                                  NaN
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                      Nexus Solutions
# 41                         InnovateTech
# 42                               Verato
# 43                                  EAI
# 44                                 AISH
# 45  Institute for Experiential AI (EAI)
# 46                         InnovateTech
# 47                GlobalCorp Industries
# 48                     Vertex Analytics
# 49                Sterling Technologies
#
#                                      job_role           job_id  \
# 0                     Research Data Scientist
# 1                   Enterprise Data Scientist           121420
# 2                           Sr. Data Analyst
# 3            Software Engineer II - Data Lake
# 4                                 pack member
# 5         Data Scientist (Associate - Senior)
# 6            Data Scientist, Cryo-ET & AI/ML
# 7                  Machine Learning Scientist  diffUSE project
# 8   Senior Machine Learning Engineer, App Ads
# 9                                       other
# 10                                        NaN              NaN
# 11                                        NaN              NaN
# 12                                        NaN              NaN
# 13                                        NaN              NaN
# 14                                        NaN              NaN
# 15                                        NaN              NaN
# 16                                        NaN              NaN
# 17                                        NaN              NaN
# 18                                        NaN              NaN
# 19                                        NaN              NaN
# 20                                        NaN              NaN
# 21                                        NaN              NaN
# 22                                        NaN              NaN
# 23                                        NaN              NaN
# 24                                        NaN              NaN
# 25                                        NaN              NaN
# 26                                        NaN              NaN
# 27                                        NaN              NaN
# 28                             Data Scientist
# 29                                        NaN              NaN
# 30                                        NaN              NaN
# 31                                        NaN              NaN
# 32                                        NaN              NaN
# 33                                        NaN              NaN
# 34                                        NaN              NaN
# 35                                        NaN              NaN
# 36                                        NaN              NaN
# 37                                        NaN              NaN
# 38                                        NaN              NaN
# 39                                        NaN              NaN
# 40                          Marketing Manager
# 41                         Software Developer
# 42                        Data Science Intern
# 43      Grad Coop for Data Scientist/Engineer
# 44                                   Director
# 45                        Data Engineer Co-op              N/A
# 46                   Senior Software Engineer
# 47                         Marketing Director
# 48                       Senior Data Engineer
# 49         Vice President of Product Strategy
#
#          application_status                              sent_by
# 0                   applied              iSpot Recruiting Team\n
# 1                   applied                      Recruiting Team
# 2                 interview                      The GoodRx Team
# 3                   applied  The Klaviyo Talent Acquisition Team
# 4                   applied                        Embark Team\n
# 5                  rejected               AEP Talent Acquisition
# 6                  rejected    Chan Zuckerberg Imaging Institute
# 7                  rejected               The Astera Hiring Team
# 8                  rejected                    The Reddit Team\n
# 9   WebMD Recruiting Team\n                                  NaN
# 10                      NaN                                  NaN
# 11                      NaN                                  NaN
# 12                      NaN                                  NaN
# 13                      NaN                                  NaN
# 14                      NaN                                  NaN
# 15                      NaN                                  NaN
# 16                      NaN                                  NaN
# 17                      NaN                                  NaN
# 18                      NaN                                  NaN
# 19                      NaN                                  NaN
# 20                      NaN                                  NaN
# 21                      NaN                                  NaN
# 22                      NaN                                  NaN
# 23                      NaN                                  NaN
# 24                      NaN                                  NaN
# 25                      NaN                                  NaN
# 26                      NaN                                  NaN
# 27                      NaN                                  NaN
# 28   application incomplete         Ford Talent Acquisition Team
# 29                      NaN                                  NaN
# 30                      NaN                                  NaN
# 31                      NaN                                  NaN
# 32                      NaN                                  NaN
# 33                      NaN                                  NaN
# 34                      NaN                                  NaN
# 35                      NaN                                  NaN
# 36                      NaN                                  NaN
# 37                      NaN                                  NaN
# 38                      NaN                                  NaN
# 39                      NaN                                  NaN
# 40                interview         Human Resources Department\n
# 41                interview                     Sarah Mitchell\n
# 42                interview                 Kahlil John Somera\n
# 43                interview                            Rakshitha
# 44                interview                            Rakshitha
# 45              job offered                       James Shanahan
# 46              job offered                            Alex Chen
# 47              job offered                   Michael Thompson\n
# 48              job offered                     Laura Mitchell\n
# 49              job offered                       Janet Howard\n

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt1, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER                       company_name  \
# 0         True        False         False                              iSpot
# 1         True        False         False                    CHS Career Site
# 2         True         True         False                             GoodRx
# 3         True        False         False                            Klaviyo
# 4         True        False         False                             Embark
# 5         True        False         False                                AEP
# 6         True        False         False  Chan Zuckerberg Imaging Institute
# 7         True        False         False                             Astera
# 8         True        False         False                             Reddit
# 9         True        False         False                              WebMD
# 10       False         True         False                                NaN
# 11       False         True         False                                NaN
# 12       False         True         False                                NaN
# 13       False         True         False                                NaN
# 14       False         True         False                                NaN
# 15       False         True         False                                NaN
# 16       False         True         False                                NaN
# 17       False         True         False                                NaN
# 18       False         True         False                                NaN
# 19       False         True         False                                NaN
# 20       False        False          True                                NaN
# 21       False        False          True                                NaN
# 22       False        False          True                                NaN
# 23       False        False          True                                NaN
# 24       False        False          True                                NaN
# 25       False        False          True                                NaN
# 26       False        False          True                                NaN
# 27       False        False          True                                NaN
# 28        True        False         False                               Ford
# 29       False        False          True                                NaN
# 30       False        False          True                                NaN
# 31       False         True         False                                NaN
# 32       False         True         False                                NaN
# 33       False         True         False                                NaN
# 34       False         True         False                                NaN
# 35       False         True         False                                NaN
# 36       False        False          True                                NaN
# 37       False        False          True                                NaN
# 38       False        False          True                                NaN
# 39       False        False          True                                NaN
# 40        True         True         False                    Nexus Solutions
# 41        True         True         False                       InnovateTech
# 42        True         True         False                             Verato
# 43        True         True         False                                EAI
# 44        True         True         False
# 45        True        False         False            Northeastern University
# 46        True        False         False                       InnovateTech
# 47        True        False         False              GlobalCorp Industries
# 48        True        False         False                   Vertex Analytics
# 49        True        False         False              Sterling Technologies
#
#                                           job_role                    job_id  \
# 0                          Research Data Scientist
# 1                        Enterprise Data Scientist                    121420
# 2                                 Sr. Data Analyst
# 3                 Software Engineer II - Data Lake
# 4                                                ,                  ,applied
# 5              Data Scientist (Associate - Senior)
# 6                  Data Scientist, Cryo-ET & AI/ML
# 7                       Machine Learning Scientist
# 8        Senior Machine Learning Engineer, App Ads
# 9
# 10                                             NaN                       NaN
# 11                                             NaN                       NaN
# 12                                             NaN                       NaN
# 13                                             NaN                       NaN
# 14                                             NaN                       NaN
# 15                                             NaN                       NaN
# 16                                             NaN                       NaN
# 17                                             NaN                       NaN
# 18                                             NaN                       NaN
# 19                                             NaN                       NaN
# 20                                             NaN                       NaN
# 21                                             NaN                       NaN
# 22                                             NaN                       NaN
# 23                                             NaN                       NaN
# 24                                             NaN                       NaN
# 25                                             NaN                       NaN
# 26                                             NaN                       NaN
# 27                                             NaN                       NaN
# 28                                  Data Scientist
# 29                                             NaN                       NaN
# 30                                             NaN                       NaN
# 31                                             NaN                       NaN
# 32                                             NaN                       NaN
# 33                                             NaN                       NaN
# 34                                             NaN                       NaN
# 35                                             NaN                       NaN
# 36                                             NaN                       NaN
# 37                                             NaN                       NaN
# 38                                             NaN                       NaN
# 39                                             NaN                       NaN
# 40                               Marketing Manager
# 41                              Software Developer
# 42                             Data Science Intern
# 43           Grad Coop for Data Scientist/Engineer
# 44                                Director of AISH  May 24th  at 1:30 PM EST
# 45                             Data Engineer Co-op
# 46                        Senior Software Engineer
# 47  Marketing Director, Consumer Products Division
# 48                            Senior Data Engineer
# 49              Vice President of Product Strategy
#
#         application_status                              sent_by
# 0                  applied                iSpot Recruiting Team
# 1                  applied                      Recruiting Team
# 2                interview                      The GoodRx Team
# 3                  applied  The Klaviyo Talent Acquisition Team
# 4              Embark Team                                  NaN
# 5                 rejected               AEP Talent Acquisition
# 6                 rejected    Chan Zuckerberg Imaging Institute
# 7                 rejected               The Astera Hiring Team
# 8                 rejected                      The Reddit Team
# 9                 rejected            The WebMD Recruiting Team
# 10                     NaN                                  NaN
# 11                     NaN                                  NaN
# 12                     NaN                                  NaN
# 13                     NaN                                  NaN
# 14                     NaN                                  NaN
# 15                     NaN                                  NaN
# 16                     NaN                                  NaN
# 17                     NaN                                  NaN
# 18                     NaN                                  NaN
# 19                     NaN                                  NaN
# 20                     NaN                                  NaN
# 21                     NaN                                  NaN
# 22                     NaN                                  NaN
# 23                     NaN                                  NaN
# 24                     NaN                                  NaN
# 25                     NaN                                  NaN
# 26                     NaN                                  NaN
# 27                     NaN                                  NaN
# 28  application incomplete         Ford Talent Acquisition Team
# 29                     NaN                                  NaN
# 30                     NaN                                  NaN
# 31                     NaN                                  NaN
# 32                     NaN                                  NaN
# 33                     NaN                                  NaN
# 34                     NaN                                  NaN
# 35                     NaN                                  NaN
# 36                     NaN                                  NaN
# 37                     NaN                                  NaN
# 38                     NaN                                  NaN
# 39                     NaN                                  NaN
# 40               interview           Human Resources Department
# 41               interview                       Sarah Mitchell
# 42               interview                   Kahlil John Somera
# 43               interview                            Rakshitha
# 44               interview                            Rakshitha
# 45             job offered                       James Shanahan
# 46             job offered                            Alex Chen
# 47             job offered                     Michael Thompson
# 48             job offered                       Laura Mitchell
# 49             job offered                         Janet Howard

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
# ----> 3     data_df
#       4     .apply(lambda row: job_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[14], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
#       3     data_df
# ----> 4     .apply(lambda row: job_information_extraction(row, info_extract_prompt1, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in job_information_extraction(row, prompt_msg, model, token, examples)
#      53 def job_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_JOB']) == True:
# ---> 55         result = extract_JOB_info(model, token, prompt_msg, row['email'], examples)
#      56         return result
#      58     else:
#
# Cell In[4], line 49, in extract_JOB_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %% [markdown]
# ### Prompt-2 test

# %%
info_extract_prompt2 = """You are an information extraction assistant.  
You will be given the full text of an email regarding a candidate’s job application status.

Your task is to read the email carefully and extract the following details exactly as they appear in the email (or return empty string "" if the detail is missing):

1. Company Name — The company or organization sending the email. This referes to the name of the company that is mentioned in the email and does not necessarily refer to the sender's name. For example, if the email is sent by Amazon talent acquisition team or Amazon career site or Amazon hiring manager, etc., the company name is Amazon.
2. Job Role — The job title or role mentioned in the email.
3. Job ID — The job requisition ID, reference number, or posting number mentioned.
4. Application Status — One of the following categories that best describes the current stage:
   - application incomplete : emails that mention application is not complete
   - applied : emails that convey that the candidate has applied for the job
   - assessment: emails that mention about an assessment or evaluation process after being shortlisted.
   - interview: emails that mention about an interview process. Contains text talking about the interview process, schedule, format, etc. Do not base the decision based on the sender's email.
   - job offered: emails that mention that the candidate has been offered a job.
   - rejected: emails that mention that the candidate has been rejected for the job.
   - withdrawn: emails that mention that the candidate has withdrawn their application.
   - other (if none of the above applies): if the email does not fit into any of the above categories, return "other".
5. Email Sent by - The sender of the email. It can be the person, talent acquisition team, etc.

### Output format:
<company_name>|<job_role>|<job_id>|<application_status>|<sent_by>

Return the extracted information in the format above, with each detail separated by a pipe, without any additional text or metadata. If any detail is not present in the email, return an empty string for that detail (e.g., if the job ID is not mentioned, return <company_name>|<job_role>||<application_status>|<sent_by>)."""

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt2, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER  \
# 0         True        False         False
# 1         True        False         False
# 2         True         True         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False
#
#                            company_name  \
# 0                                 iSpot
# 1                       CHS Career Site
# 2                                GoodRx
# 3                               Klaviyo
# 4                                Embark
# 5                                   AEP
# 6     Chan Zuckerberg Imaging Institute
# 7                                Astera
# 8                                Reddit
# 9                            PulsePoint
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                 Ford
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34                                  NaN
# 35                                  NaN
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                      Nexus Solutions
# 41                         InnovateTech
# 42                               Verato
# 43                                  EAI
# 44                                 AISH
# 45  Institute for Experiential AI (EAI)
# 46                         InnovateTech
# 47                GlobalCorp Industries
# 48                     Vertex Analytics
# 49                Sterling Technologies
#
#                                           job_role     job_id  \
# 0                          Research Data Scientist
# 1                        Enterprise Data Scientist     121420
# 2                                 Sr. Data Analyst
# 3                 Software Engineer II - Data Lake
# 4                               future pack member
# 5              Data Scientist (Associate - Senior)
# 6                  Data Scientist, Cryo-ET & AI/ML
# 7                       Machine Learning Scientist
# 8        Senior Machine Learning Engineer, App Ads
# 9                                              job
# 10                                             NaN        NaN
# 11                                             NaN        NaN
# 12                                             NaN        NaN
# 13                                             NaN        NaN
# 14                                             NaN        NaN
# 15                                             NaN        NaN
# 16                                             NaN        NaN
# 17                                             NaN        NaN
# 18                                             NaN        NaN
# 19                                             NaN        NaN
# 20                                             NaN        NaN
# 21                                             NaN        NaN
# 22                                             NaN        NaN
# 23                                             NaN        NaN
# 24                                             NaN        NaN
# 25                                             NaN        NaN
# 26                                             NaN        NaN
# 27                                             NaN        NaN
# 28                                  Data Scientist
# 29                                             NaN        NaN
# 30                                             NaN        NaN
# 31                                             NaN        NaN
# 32                                             NaN        NaN
# 33                                             NaN        NaN
# 34                                             NaN        NaN
# 35                                             NaN        NaN
# 36                                             NaN        NaN
# 37                                             NaN        NaN
# 38                                             NaN        NaN
# 39                                             NaN        NaN
# 40                               Marketing Manager
# 41                              Software Developer
# 42                             Data Science Intern
# 43           Grad Coop for Data Scientist/Engineer
# 44                                        Director
# 45                             Data Engineer Co-op  No Job ID
# 46                        Senior Software Engineer
# 47  Marketing Director, Consumer Products Division
# 48                            Senior Data Engineer
# 49              Vice President of Product Strategy
#
#         application_status                              sent_by
# 0                  applied              iSpot Recruiting Team\n
# 1                  applied    CHS Career Site Recruiting Team\n
# 2                interview                      The GoodRx Team
# 3                  applied  The Klaviyo Talent Acquisition Team
# 4                  applied                          Embark Team
# 5                 rejected               AEP Talent Acquisition
# 6                 rejected    Chan Zuckerberg Imaging Institute
# 7                 rejected               The Astera Hiring Team
# 8                 rejected                      The Reddit Team
# 9                 rejected            The WebMD Recruiting Team
# 10                     NaN                                  NaN
# 11                     NaN                                  NaN
# 12                     NaN                                  NaN
# 13                     NaN                                  NaN
# 14                     NaN                                  NaN
# 15                     NaN                                  NaN
# 16                     NaN                                  NaN
# 17                     NaN                                  NaN
# 18                     NaN                                  NaN
# 19                     NaN                                  NaN
# 20                     NaN                                  NaN
# 21                     NaN                                  NaN
# 22                     NaN                                  NaN
# 23                     NaN                                  NaN
# 24                     NaN                                  NaN
# 25                     NaN                                  NaN
# 26                     NaN                                  NaN
# 27                     NaN                                  NaN
# 28  application incomplete         Ford Talent Acquisition Team
# 29                     NaN                                  NaN
# 30                     NaN                                  NaN
# 31                     NaN                                  NaN
# 32                     NaN                                  NaN
# 33                     NaN                                  NaN
# 34                     NaN                                  NaN
# 35                     NaN                                  NaN
# 36                     NaN                                  NaN
# 37                     NaN                                  NaN
# 38                     NaN                                  NaN
# 39                     NaN                                  NaN
# 40               interview         Human Resources Department\n
# 41               interview                     Sarah Mitchell\n
# 42               interview                 Kahlil John Somera\n
# 43               interview                            Rakshitha
# 44               interview                            Rakshitha
# 45             job offered                       James Shanahan
# 46             job offered                            Alex Chen
# 47             job offered                   Michael Thompson\n
# 48             job offered                     Laura Mitchell\n
# 49             job offered                       Janet Howard\n

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt2, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER                       company_name  \
# 0         True        False         False                              iSpot
# 1         True        False         False                                CHS
# 2         True         True         False                             GoodRx
# 3         True        False         False                            Klaviyo
# 4         True        False         False                             Embark
# 5         True        False         False                                AEP
# 6         True        False         False  Chan Zuckerberg Imaging Institute
# 7         True        False         False                             Astera
# 8         True        False         False                             Reddit
# 9         True        False         False                              WebMD
# 10       False         True         False                                NaN
# 11       False         True         False                                NaN
# 12       False         True         False                                NaN
# 13       False         True         False                                NaN
# 14       False         True         False                                NaN
# 15       False         True         False                                NaN
# 16       False         True         False                                NaN
# 17       False         True         False                                NaN
# 18       False         True         False                                NaN
# 19       False         True         False                                NaN
# 20       False        False          True                                NaN
# 21       False        False          True                                NaN
# 22       False        False          True                                NaN
# 23       False        False          True                                NaN
# 24       False        False          True                                NaN
# 25       False        False          True                                NaN
# 26       False        False          True                                NaN
# 27       False        False          True                                NaN
# 28        True        False         False                               Ford
# 29       False        False          True                                NaN
# 30       False        False          True                                NaN
# 31       False         True         False                                NaN
# 32       False         True         False                                NaN
# 33       False         True         False                                NaN
# 34       False         True         False                                NaN
# 35       False         True         False                                NaN
# 36       False        False          True                                NaN
# 37       False        False          True                                NaN
# 38       False        False          True                                NaN
# 39       False        False          True                                NaN
# 40        True         True         False                    Nexus Solutions
# 41        True         True         False                       InnovateTech
# 42        True         True         False                             Verato
# 43        True         True         False                                EAI
# 44        True         True         False
# 45        True        False         False            Northeastern University
# 46        True        False         False                       InnovateTech
# 47        True        False         False              GlobalCorp Industries
# 48        True        False         False                   Vertex Analytics
# 49        True        False         False              Sterling Technologies
#
#                                           job_role  job_id  \
# 0                          Research Data Scientist
# 1                        Enterprise Data Scientist  121420
# 2                                 Sr. Data Analyst
# 3                 Software Engineer II - Data Lake
# 4
# 5              Data Scientist (Associate - Senior)
# 6                  Data Scientist, Cryo-ET & AI/ML
# 7                       Machine Learning Scientist
# 8        Senior Machine Learning Engineer, App Ads
# 9
# 10                                             NaN     NaN
# 11                                             NaN     NaN
# 12                                             NaN     NaN
# 13                                             NaN     NaN
# 14                                             NaN     NaN
# 15                                             NaN     NaN
# 16                                             NaN     NaN
# 17                                             NaN     NaN
# 18                                             NaN     NaN
# 19                                             NaN     NaN
# 20                                             NaN     NaN
# 21                                             NaN     NaN
# 22                                             NaN     NaN
# 23                                             NaN     NaN
# 24                                             NaN     NaN
# 25                                             NaN     NaN
# 26                                             NaN     NaN
# 27                                             NaN     NaN
# 28
# 29                                             NaN     NaN
# 30                                             NaN     NaN
# 31                                             NaN     NaN
# 32                                             NaN     NaN
# 33                                             NaN     NaN
# 34                                             NaN     NaN
# 35                                             NaN     NaN
# 36                                             NaN     NaN
# 37                                             NaN     NaN
# 38                                             NaN     NaN
# 39                                             NaN     NaN
# 40                               Marketing Manager
# 41                              Software Developer
# 42                             Data Science Intern
# 43           Grad Coop for Data Scientist/Engineer
# 44                                Director of AISH
# 45                             Data Engineer Co-op
# 46                        Senior Software Engineer
# 47  Marketing Director, Consumer Products Division
# 48                            Senior Data Engineer
# 49              Vice President of Product Strategy
#
#         application_status                              sent_by
# 0                  applied                iSpot Recruiting Team
# 1                  applied                      CHS Career Site
# 2                interview                      The GoodRx Team
# 3                  applied  The Klaviyo Talent Acquisition Team
# 4                  applied                          Embark Team
# 5                 rejected               AEP Talent Acquisition
# 6                 rejected    Chan Zuckerberg Imaging Institute
# 7                 rejected               The Astera Hiring Team
# 8                 rejected                      The Reddit Team
# 9                 rejected            The WebMD Recruiting Team
# 10                     NaN                                  NaN
# 11                     NaN                                  NaN
# 12                     NaN                                  NaN
# 13                     NaN                                  NaN
# 14                     NaN                                  NaN
# 15                     NaN                                  NaN
# 16                     NaN                                  NaN
# 17                     NaN                                  NaN
# 18                     NaN                                  NaN
# 19                     NaN                                  NaN
# 20                     NaN                                  NaN
# 21                     NaN                                  NaN
# 22                     NaN                                  NaN
# 23                     NaN                                  NaN
# 24                     NaN                                  NaN
# 25                     NaN                                  NaN
# 26                     NaN                                  NaN
# 27                     NaN                                  NaN
# 28  application incomplete         Ford Talent Acquisition Team
# 29                     NaN                                  NaN
# 30                     NaN                                  NaN
# 31                     NaN                                  NaN
# 32                     NaN                                  NaN
# 33                     NaN                                  NaN
# 34                     NaN                                  NaN
# 35                     NaN                                  NaN
# 36                     NaN                                  NaN
# 37                     NaN                                  NaN
# 38                     NaN                                  NaN
# 39                     NaN                                  NaN
# 40               interview           Human Resources Department
# 41               interview                       Sarah Mitchell
# 42               interview                   Kahlil John Somera
# 43               interview                            Rakshitha
# 44               interview                            Rakshitha
# 45             job offered                       James Shanahan
# 46             job offered                            Alex Chen
# 47             job offered                     Michael Thompson
# 48             job offered                       Laura Mitchell
# 49             job offered                         Janet Howard

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
# ----> 3     data_df
#       4     .apply(lambda row: job_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[18], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
#       3     data_df
# ----> 4     .apply(lambda row: job_information_extraction(row, info_extract_prompt2, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in job_information_extraction(row, prompt_msg, model, token, examples)
#      53 def job_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_JOB']) == True:
# ---> 55         result = extract_JOB_info(model, token, prompt_msg, row['email'], examples)
#      56         return result
#      58     else:
#
# Cell In[4], line 49, in extract_JOB_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %% [markdown]
# ### Prompt-3 test

# %%
info_extract_prompt3 = f"""**Task Description:**
    You are an expert at extracting structured information from emails.
    Your task is to analyze the following email and extract details about a job application.
    Please read the email carefully and identify the required fields.

    **Output Format:**
    Provide the output as a single line of pipe-delimited (`|`) text. Do not include any explanatory text before or after the result.
    The fields must be in the following exact order:
    `company_name|job_role|job_id|application_status|sent_by`
    Use `unknown` for any optional fields that are not present in the email.

    **Field Definitions:**
    * `company_name`: The name of the company that sent the application status email. This is a required field.
    * `job_role`: The specific job title or role mentioned in the email (e.g., "Software Engineer", "Product Manager"). If not specified, use null.
    * `job_id`: The unique identifier for the job posting. If not specified, use null.
    * `application_status`: The current status of the application. Choose one of the following options:
        -   `applied`: The application has been successfully submitted and received.
        -   `assessment`: The candidate is asked to complete a test or assessment.
        -   `interview`: The candidate is invited for an interview (phone, video, or in-person).
        -   `job offered`: The candidate has been offered the job.
        -   `rejected`: The company has decided not to move forward with the application.
        -   `withdrawn`: The candidate has withdrawn their application.
        -   `application incomplete`: The application is missing information and needs action.
        -   `other`: The status does not fit into any of the above categories.
    * `sent_by`: The name of the person, team, or system that sent the email (e.g., "Jane Doe", "The Google Recruitment Team", "no-reply@greenhouse.io").

    **Few-Shot Examples:**

    ---
    **Example Email 1:**
    Subject: Your application for Software Engineer at Innovate Inc.

    Hi Alex,

    Thank you for your interest in the Software Engineer (ID: SWE-123) position at Innovate Inc. We have received your application and are currently reviewing it. We will get back to you soon.

    Best,
    The Innovate Inc. Hiring Team

    **Example Pipe-Delimited Output 1:**
    Innovate Inc.|Software Engineer|SWE-123|applied|The Innovate Inc. Hiring Team
    ---
    **Example Email 2:**
    Subject: Update on your application

    Dear Jordan,

    Thank you for applying to Nebula Corp. After careful consideration, we have decided not to move forward with your candidacy at this time. We wish you the best in your job search.

    Sincerely,
    Nebula Corp. Recruiting

    **Example Pipe-Delimited Output 2:**
    Nebula Corp.|unknown|unknown|rejected|Nebula Corp. Recruiting
    """

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model1, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER  \
# 0         True        False         False
# 1         True        False         False
# 2         True         True         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False
#
#                            company_name  \
# 0                                 iSpot
# 1                       CHS Career Site
# 2                           GoodRx Team
# 3                               Klaviyo
# 4                                Embark
# 5                                   AEP
# 6     Chan Zuckerberg Imaging Institute
# 7                                Astera
# 8                                Reddit
# 9                            PulsePoint
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28         Ford Talent Acquisition Team
# 29                                  NaN
# 30                                  NaN
# 31                                  NaN
# 32                                  NaN
# 33                                  NaN
# 34                                  NaN
# 35                                  NaN
# 36                                  NaN
# 37                                  NaN
# 38                                  NaN
# 39                                  NaN
# 40                      Nexus Solutions
# 41                         InnovateTech
# 42                               Verato
# 43                                  EAI
# 44                                 AISH
# 45  Institute for Experiential AI (EAI)
# 46                         InnovateTech
# 47                GlobalCorp Industries
# 48                     Vertex Analytics
# 49                Sterling Technologies
#
#                                      job_role   job_id  \
# 0                     Research Data Scientist  unknown
# 1                   Enterprise Data Scientist   121420
# 2                            Sr. Data Analyst  unknown
# 3            Software Engineer II - Data Lake  unknown
# 4                                     unknown  unknown
# 5                              Data Scientist  unknown
# 6                              Data Scientist  unknown
# 7                  Machine Learning Scientist  unknown
# 8   Senior Machine Learning Engineer, App Ads  unknown
# 9                                     unknown  unknown
# 10                                        NaN      NaN
# 11                                        NaN      NaN
# 12                                        NaN      NaN
# 13                                        NaN      NaN
# 14                                        NaN      NaN
# 15                                        NaN      NaN
# 16                                        NaN      NaN
# 17                                        NaN      NaN
# 18                                        NaN      NaN
# 19                                        NaN      NaN
# 20                                        NaN      NaN
# 21                                        NaN      NaN
# 22                                        NaN      NaN
# 23                                        NaN      NaN
# 24                                        NaN      NaN
# 25                                        NaN      NaN
# 26                                        NaN      NaN
# 27                                        NaN      NaN
# 28                             Data Scientist  unknown
# 29                                        NaN      NaN
# 30                                        NaN      NaN
# 31                                        NaN      NaN
# 32                                        NaN      NaN
# 33                                        NaN      NaN
# 34                                        NaN      NaN
# 35                                        NaN      NaN
# 36                                        NaN      NaN
# 37                                        NaN      NaN
# 38                                        NaN      NaN
# 39                                        NaN      NaN
# 40                          Marketing Manager  unknown
# 41                         Software Developer  unknown
# 42                        Data Science Intern  unknown
# 43                    Data Scientist/Engineer  unknown
# 44                                    unknown  unknown
# 45                        Data Engineer Co-op  unknown
# 46                   Senior Software Engineer  unknown
# 47                         Marketing Director  unknown
# 48                       Senior Data Engineer  unknown
# 49         Vice President of Product Strategy  unknown
#
#         application_status                                sent_by
# 0                  applied                iSpot Recruiting Team\n
# 1                  applied                        Recruiting Team
# 2   application incomplete                      The GoodRx Team\n
# 3                  applied  The Klaviyo Talent Acquisition Team\n
# 4                  applied                          Embark Team\n
# 5                 rejected               AEP Talent Acquisition\n
# 6                 rejected      Chan Zuckerberg Imaging Institute
# 7                 rejected               The Astera Hiring Team\n
# 8                 rejected                      The Reddit Team\n
# 9                 rejected            The WebMD Recruiting Team\n
# 10                     NaN                                    NaN
# 11                     NaN                                    NaN
# 12                     NaN                                    NaN
# 13                     NaN                                    NaN
# 14                     NaN                                    NaN
# 15                     NaN                                    NaN
# 16                     NaN                                    NaN
# 17                     NaN                                    NaN
# 18                     NaN                                    NaN
# 19                     NaN                                    NaN
# 20                     NaN                                    NaN
# 21                     NaN                                    NaN
# 22                     NaN                                    NaN
# 23                     NaN                                    NaN
# 24                     NaN                                    NaN
# 25                     NaN                                    NaN
# 26                     NaN                                    NaN
# 27                     NaN                                    NaN
# 28                 applied         Ford Talent Acquisition Team\n
# 29                     NaN                                    NaN
# 30                     NaN                                    NaN
# 31                     NaN                                    NaN
# 32                     NaN                                    NaN
# 33                     NaN                                    NaN
# 34                     NaN                                    NaN
# 35                     NaN                                    NaN
# 36                     NaN                                    NaN
# 37                     NaN                                    NaN
# 38                     NaN                                    NaN
# 39                     NaN                                    NaN
# 40               interview           Human Resources Department\n
# 41               interview                       Sarah Mitchell\n
# 42               interview                   Kahlil John Somera\n
# 43               interview                              Rakshitha
# 44               interview                            Rakshitha\n
# 45             job offered                   Alev B. Aydin-Jensen
# 46             job offered                              Alex Chen
# 47             job offered                       Michael Thompson
# 48             job offered                         Laura Mitchell
# 49             job offered                           Janet Howard

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model2, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
#                                                 email    JOB   MEET  OTHER  \
# 0   Hi Saideep,\n\nThanks for your interest in iSp...   True  False  False
# 1   Hello, Saideep,\n\nWe received your job applic...   True  False  False
# 2   Hi Saideep,\n\nWe're super-pumped that you sha...   True  False  False
# 3   Hi Saideep,\n\nThank you for applying to the S...   True  False  False
# 4   Hello Saideep,\n\nThank you for your interest ...   True  False  False
# 5   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 6   Dear Saideep,\n\nThank you for your interest i...   True  False  False
# 7   Hi Saideep,\nThank you for your interest in th...   True  False  False
# 8   Hi Saideep,\n\nThanks for your interest in Red...   True  False  False
# 9   Dear Saideep,\n\nThank you for giving us the o...   True  False  False
# 10  Hi Sarah,\nHope your week is going well! I've ...  False   True  False
# 11  Hey Tom,\nCan we hop on a quick call tomorrow ...  False   True  False
# 12  Dear Jennifer,\nI hope this email finds you we...  False   True  False
# 13  Hi Rebecca,\nI know this is short notice, but ...  False   True  False
# 14  Hello Amanda,\nIt was great meeting you at the...  False   True  False
# 15  Hey Lisa,\nThe wireframes for the mobile app r...  False   True  False
# 16  Dear Robert,\nMy name is Patricia Gonzalez, an...  False   True  False
# 17  Hi Kevin,\nI loved your short film at the Port...  False   True  False
# 18  Good morning Catherine,\nI trust you had a res...  False   True  False
# 19  Hey Carlos,\nHope you're surviving the heat wa...  False   True  False
# 20  Hello @saideep-arikontham,\n\nWe are upgrading...  False  False   True
# 21  Welcome back D.B.!\nIf you requested to log in...  False  False   True
# 22  Hello saideepreddy99@gmail.com,\nPlease click ...  False  False   True
# 23  Dear Customer,\n\nYour MRP 359 for Jio Number ...  False  False   True
# 24  Welcome to TrueUp!\nThank you for signing up. ...  False  False   True
# 25  Dear Google User,\n\nWe received a request to ...  False  False   True
# 26  Dear Saideep,\t\n \nThe following subscription...  False  False   True
# 27  Hello Saideep,\n\nYou might be a great fit for...  False  False   True
# 28  Hello Saideep,\n\nThank you for beginning the ...   True  False  False
# 29  Your Top Job matches from Jobright - July 31\n...  False  False   True
# 30  \n\nHi Saideep Reddy Arikontham,\n\nWe noticed...  False  False   True
# 31  Dear Ms. Rodriguez,\nI'd like to schedule an i...  False   True  False
# 32  Hey Jake!\nIt's been way too long since we con...  False   True  False
# 33  Hi Tom,\nWe need to discuss the client situati...  False   True  False
# 34  Agent Smith,\nYour mission, should you choose ...  False   True  False
# 35  Dear Professor Williams,\nI hope this email fi...  False   True  False
# 36  Team,\nOur office fern, Gerald, is looking a b...  False  False   True
# 37  Hi Emma,\nI was just thinking about how much y...  False  False   True
# 38  Hey everyone,\nDo you ever wonder why we say "...  False  False   True
# 39  Friends!\nI can barely type because my hands a...  False  False   True
# 40  Dear Ms. Chen,\nWe hope this message finds you...   True   True  False
# 41  Hi Mike,\nGreat news! The engineering team lov...   True   True  False
# 42  Hi Saideep,\n\n\n\nThanks for your interest in...   True   True  False
# 43  Hi Saideep,\n \nThis is Rakshitha, part of the...   True   True  False
# 44  Dear Saideep,\n\n\n\nGreetings!!\n\nYour inter...   True   True  False
# 45  Date: 05/30/2024\nName: Saideep Reddy Arikonth...   True  False  False
# 46  Dear Sarah,\nI hope this email finds you well!...   True  False  False
# 47  Dear Ms. Rodriguez,\nFollowing your interview ...   True  False  False
# 48  Dear James,\n\nWe are delighted to extend to y...   True  False  False
# 49  Dear Michael,\n\nFollowing our recent conversa...   True  False  False
#
#    mistral_JOB mistral_MEET mistral_OTHER  \
# 0         True        False         False
# 1         True        False         False
# 2         True         True         False
# 3         True        False         False
# 4         True        False         False
# 5         True        False         False
# 6         True        False         False
# 7         True        False         False
# 8         True        False         False
# 9         True        False         False
# 10       False         True         False
# 11       False         True         False
# 12       False         True         False
# 13       False         True         False
# 14       False         True         False
# 15       False         True         False
# 16       False         True         False
# 17       False         True         False
# 18       False         True         False
# 19       False         True         False
# 20       False        False          True
# 21       False        False          True
# 22       False        False          True
# 23       False        False          True
# 24       False        False          True
# 25       False        False          True
# 26       False        False          True
# 27       False        False          True
# 28        True        False         False
# 29       False        False          True
# 30       False        False          True
# 31       False         True         False
# 32       False         True         False
# 33       False         True         False
# 34       False         True         False
# 35       False         True         False
# 36       False        False          True
# 37       False        False          True
# 38       False        False          True
# 39       False        False          True
# 40        True         True         False
# 41        True         True         False
# 42        True         True         False
# 43        True         True         False
# 44        True         True         False
# 45        True        False         False
# 46        True        False         False
# 47        True        False         False
# 48        True        False         False
# 49        True        False         False
#
#                                          company_name  \
# 0                                               iSpot
# 1                                     CHS Career Site
# 2                                              GoodRx
# 3                                             Klaviyo
# 4                                              Embark
# 5                                                 AEP
# 6                   Chan Zuckerberg Imaging Institute
# 7                                              Astera
# 8                                              Reddit
# 9                                               WebMD
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                               Ford
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                    Nexus Solutions
# 41                                       InnovateTech
# 42                                             Verato
# 43                                                EAI
# 44                                               AISH
# 45  Institute for Experiential AI (EAI) at Northea...
# 46                                       InnovateTech
# 47                              GlobalCorp Industries
# 48                                   Vertex Analytics
# 49                              Sterling Technologies
#
#                                      job_role   job_id  \
# 0                     Research Data Scientist  unknown
# 1                   Enterprise Data Scientist   121420
# 2                            Sr. Data Analyst  unknown
# 3            Software Engineer II - Data Lake  unknown
# 4                                     unknown  unknown
# 5         Data Scientist (Associate - Senior)  unknown
# 6             Data Scientist, Cryo-ET & AI/ML  unknown
# 7                  Machine Learning Scientist  unknown
# 8   Senior Machine Learning Engineer, App Ads  unknown
# 9                                     unknown  unknown
# 10                                        NaN      NaN
# 11                                        NaN      NaN
# 12                                        NaN      NaN
# 13                                        NaN      NaN
# 14                                        NaN      NaN
# 15                                        NaN      NaN
# 16                                        NaN      NaN
# 17                                        NaN      NaN
# 18                                        NaN      NaN
# 19                                        NaN      NaN
# 20                                        NaN      NaN
# 21                                        NaN      NaN
# 22                                        NaN      NaN
# 23                                        NaN      NaN
# 24                                        NaN      NaN
# 25                                        NaN      NaN
# 26                                        NaN      NaN
# 27                                        NaN      NaN
# 28                             Data Scientist  unknown
# 29                                        NaN      NaN
# 30                                        NaN      NaN
# 31                                        NaN      NaN
# 32                                        NaN      NaN
# 33                                        NaN      NaN
# 34                                        NaN      NaN
# 35                                        NaN      NaN
# 36                                        NaN      NaN
# 37                                        NaN      NaN
# 38                                        NaN      NaN
# 39                                        NaN      NaN
# 40                          Marketing Manager  unknown
# 41                         Software Developer  unknown
# 42                        Data Science Intern  unknown
# 43      Grad Coop for Data Scientist/Engineer  unknown
# 44                                    unknown  unknown
# 45                        Data Engineer Co-op  unknown
# 46                   Senior Software Engineer  unknown
# 47                         Marketing Director  unknown
# 48                       Senior Data Engineer  unknown
# 49         Vice President of Product Strategy  unknown
#
#         application_status                              sent_by
# 0                  applied                iSpot Recruiting Team
# 1                  applied      CHS Career Site Recruiting Team
# 2                  applied                      The GoodRx Team
# 3                  applied  The Klaviyo Talent Acquisition Team
# 4                  applied                          Embark Team
# 5                 rejected               AEP Talent Acquisition
# 6                 rejected    Chan Zuckerberg Imaging Institute
# 7                 rejected               The Astera Hiring Team
# 8                 rejected                      The Reddit Team
# 9                 rejected            The WebMD Recruiting Team
# 10                     NaN                                  NaN
# 11                     NaN                                  NaN
# 12                     NaN                                  NaN
# 13                     NaN                                  NaN
# 14                     NaN                                  NaN
# 15                     NaN                                  NaN
# 16                     NaN                                  NaN
# 17                     NaN                                  NaN
# 18                     NaN                                  NaN
# 19                     NaN                                  NaN
# 20                     NaN                                  NaN
# 21                     NaN                                  NaN
# 22                     NaN                                  NaN
# 23                     NaN                                  NaN
# 24                     NaN                                  NaN
# 25                     NaN                                  NaN
# 26                     NaN                                  NaN
# 27                     NaN                                  NaN
# 28  application incomplete         Ford Talent Acquisition Team
# 29                     NaN                                  NaN
# 30                     NaN                                  NaN
# 31                     NaN                                  NaN
# 32                     NaN                                  NaN
# 33                     NaN                                  NaN
# 34                     NaN                                  NaN
# 35                     NaN                                  NaN
# 36                     NaN                                  NaN
# 37                     NaN                                  NaN
# 38                     NaN                                  NaN
# 39                     NaN                                  NaN
# 40               interview           Human Resources Department
# 41               interview                       Sarah Mitchell
# 42               interview                   Kahlil John Somera
# 43               interview                            Rakshitha
# 44               interview                            Rakshitha
# 45             job offered                       James Shanahan
# 46             job offered                            Alex Chen
# 47             job offered                     Michael Thompson
# 48             job offered                       Laura Mitchell
# 49             job offered                         Janet Howard

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
# ----> 3     data_df
#       4     .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[26], line 4, in <lambda>(row)
#       1 info_data_df = data_df.copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
#       3     data_df
# ----> 4     .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in job_information_extraction(row, prompt_msg, model, token, examples)
#      53 def job_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_JOB']) == True:
# ---> 55         result = extract_JOB_info(model, token, prompt_msg, row['email'], examples)
#      56         return result
#      58     else:
#
# Cell In[4], line 49, in extract_JOB_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}

# %%
info_data_df = data_df.copy()
info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
    data_df
    .apply(lambda row: job_information_extraction(row, info_extract_prompt3, model3, token), axis=1)
    .apply(pd.Series)  # convert array to 3 separate columns
)
info_data_df
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 info_data_df = data_df.head(10).copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
# ----> 3     info_data_df
#       4     .apply(lambda row: job_information_extraction(row, info_extract_prompt3, "moonshotai/kimi-k2-instruct", token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/frame.py:10381, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10367 from pandas.core.apply import frame_apply
#   10369 op = frame_apply(
#   10370     self,
#   10371     func=func,
#    (...)
#   10379     kwargs=kwargs,
#   10380 )
# > 10381 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 4, in <lambda>(row)
#       1 info_data_df = data_df.head(10).copy()
#       2 info_data_df[['company_name', 'job_role', 'job_id', 'application_status', 'sent_by']] = (
#       3     info_data_df
# ----> 4     .apply(lambda row: job_information_extraction(row, info_extract_prompt3, "moonshotai/kimi-k2-instruct", token), axis=1)
#       5     .apply(pd.Series)  # convert array to 3 separate columns
#       6 )
#       7 info_data_df
#
# Cell In[4], line 55, in job_information_extraction(row, prompt_msg, model, token, examples)
#      53 def job_information_extraction(row, prompt_msg, model, token, examples=None):
#      54     if eval(row['mistral_JOB']) == True:
# ---> 55         result = extract_JOB_info(model, token, prompt_msg, row['email'], examples)
#      56         return result
#      58     else:
#
# Cell In[4], line 49, in extract_JOB_info(model, token, prompt_msg, email_content, examples)
#      46 chain = prompt | llm | StrOutputParser()
#      48 # Run it
# ---> 49 result = chain.invoke({"email_content": email_content})
#      50 return np.array(result.split("|"))
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/runnables/base.py:3047, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3045                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3046             else:
# -> 3047                 input_ = context.run(step.invoke, input_, config)
#    3048 # finish the root run
#    3049 except BaseException as e:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:378, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     366 @override
#     367 def invoke(
#     368     self,
#    (...)
#     373     **kwargs: Any,
#     374 ) -> BaseMessage:
#     375     config = ensure_config(config)
#     376     return cast(
#     377         "ChatGeneration",
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
#     384             run_name=config.get("run_name"),
#     385             run_id=config.pop("run_id", None),
#     386             **kwargs,
#     387         ).generations[0][0],
#     388     ).message
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:963, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     954 @override
#     955 def generate_prompt(
#     956     self,
#    (...)
#     960     **kwargs: Any,
#     961 ) -> LLMResult:
#     962     prompt_messages = [p.to_messages() for p in prompts]
# --> 963     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:782, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     779 for i, m in enumerate(input_messages):
#     780     try:
#     781         results.append(
# --> 782             self._generate_with_cache(
#     783                 m,
#     784                 stop=stop,
#     785                 run_manager=run_managers[i] if run_managers else None,
#     786                 **kwargs,
#     787             )
#     788         )
#     789     except BaseException as e:
#     790         if run_managers:
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:1028, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026     result = generate_from_stream(iter(chunks))
#    1027 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028     result = self._generate(
#    1029         messages, stop=stop, run_manager=run_manager, **kwargs
#    1030     )
#    1031 else:
#    1032     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/chat_models.py:414, in ChatNVIDIA._generate(self, messages, stop, run_manager, **kwargs)
#     412 inputs, extra_headers = _process_for_vlm(inputs, self._client.model)
#     413 payload = self._get_payload(inputs=inputs, stop=stop, stream=False, **kwargs)
# --> 414 response = self._client.get_req(payload=payload, extra_headers=extra_headers)
#     415 responses, _ = self._client.postprocess(response)
#     416 self._set_callback_out(responses, run_manager)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:498, in _NVIDIAClient.get_req(self, payload, extra_headers)
#     492 def get_req(
#     493     self,
#     494     payload: dict = {},
#     495     extra_headers: dict = {},
#     496 ) -> Response:
#     497     """Post to the API."""
# --> 498     response, session = self._post(
#     499         self.infer_url, payload, extra_headers=extra_headers
#     500     )
#     501     return self._wait(response, session)
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:394, in _NVIDIAClient._post(self, invoke_url, payload, extra_headers)
#     390 session = self.get_session_fn()
#     391 self.last_response = response = session.post(
#     392     **self.__add_authorization(self.last_inputs)
#     393 )
# --> 394 self._try_raise(response)
#     395 return response, session
#
# File ~/anaconda3/envs/mail_asst/lib/python3.10/site-packages/langchain_nvidia_ai_endpoints/_common.py:487, in _NVIDIAClient._try_raise(self, response)
#     485     body += "\nPlease check or regenerate your API key."
#     486 # todo: raise as an HTTPError
# --> 487 raise Exception(f"{header}\n{body}") from None
#
# Exception: [429] Too Many Requests
# {'status': 429, 'title': 'Too Many Requests'}
