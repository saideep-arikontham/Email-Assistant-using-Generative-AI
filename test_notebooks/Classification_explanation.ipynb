# %% [markdown]
# # Models explaining their classifications

# %% [markdown]
# ## Importing libraries

# %%
import os
import pandas as pd
from dotenv import load_dotenv
from langchain_nvidia_ai_endpoints import ChatNVIDIA
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
import warnings
warnings.filterwarnings("ignore")

### Getting Path of current file
import os
import sys
from pathlib import Path

path = Path(os.path.dirname(os.getcwd()))
path = str(path)
print(path)
sys.path.insert(1, path)
# Out:
# /Users/saideepbunny/Projects/Email-Assistant-using-Generative-AI

# %% [markdown]
# ## Setting up API keys

# %%
load_dotenv(dotenv_path=f"{path}/config/nvidia_token.env")

model1 = "google/gemma-3n-e4b-it"
model2 = "mistralai/mistral-nemotron"
model3 = "meta/llama-4-maverick-17b-128e-instruct"

token1 = os.getenv("GEMMA_API_KEY")
token2 = os.getenv("MISTRAL_API_KEY")
token3 = os.getenv("LLAMA_API_KEY")

# %% [markdown]
# ## Defining prompt

# %%
# Original classification prompt - considering Prompt-2
original_prompt = """You are an expert email classification system. Your task is to analyze the provided email and classify it into one of the three categories below. Your response must be **only** the category name and nothing else.

### **Categories**

**1. JOB**
Classify an email as `JOB` if it concerns the status of a specific job application. Recipient of the mail will be informed about the status of their application. This includes notifications that a candidate has:
*   Successfully applied for a job (only application confirmation).
*   Been invited for an assessment (online or offline).
*   Been shortlisted for a position.
*   Been invited to an interview (online or offline).
*   Been rejected for a position.

**2. MEET**
Classify an email as `MEET` if the sender is requesting to schedule an **online meeting**.
*   **Crucial Condition:** The request must be for an online/virtual meeting, NOT an in-person meeting.

**3. OTHER**
Classify an email as `OTHER` if it does not fit into the `JOB` or `MEET` categories. This includes, but is not limited to:
*   General job-related discussions that are not about application status (e.g., networking, asking about a role, advertisements or requesting for an interview).
*   Requests for an in-person or face-to-face meeting.
*   Newsletters, marketing emails, personal correspondence, etc.

**Important Rules:**
* If an email mentions a "meeting" but does not specify whether it is virtual or in-person, classify it as an online meeting.
* Any Job interview online meeting request must be classified as `JOB` category only.
* Only classify an email as JOB if it communicates a completed action related to the application status (e.g., application received, interview invitation, rejected, job offered). Do NOT classify emails with ongoing or vague updates (e.g., "Your application is under review") as JOB.


### **Output Format**

Your answer must be one of these three words exactly, with no additional text:
*   JOB
*   MEET
*   OTHER"""

# %% [markdown]
# ## Error Explanation function

# %%
def explain_classification_error(model, token, email_content, classification_prompt, predicted_label):
    """
    Use ChatPromptTemplate to explain why a classification error occurred.
    
    Args:
        email_content (str): The original email content
        true_label (str): The correct classification
        predicted_label (str): The model's prediction
        
    Returns:
        str: Explanation of the error
    """
    
    # Create the conversation template
    conversation_template = ChatPromptTemplate.from_messages([
        # Show the original classification task
        ("user", "{email_content}\n\n{classification_prompt}"),
        
        # Show the model's response
        ("assistant", "{predicted_label}"),
        
        # Ask for explanation of the classification
        ("user", """Provide an explanation for above classification:

Please analyze this email classification and provide:

**Why did you classify it as {predicted_label}?**
   - What specific parts of the email led to this decision?
   - Which keywords or phrases influenced your choice?
   - Recite the rule from the given instructions which lead to this decision

Please provide a detailed analysis in 2-3 short paragraphs.""")
    ])
    
    # Initialize the LLM
    llm = ChatNVIDIA(
        model=model,
        api_key=token,
        temperature=0.3,
        max_tokens=1024,
        streaming=False
    )
    
    # Create the chain
    chain = conversation_template | llm | StrOutputParser()
    
    # Generate explanation
    try:
        explanation = chain.invoke({
            "email_content": email_content,
            "classification_prompt": original_prompt,
            "predicted_label": predicted_label
        })
        return explanation
    except Exception as e:
        return f"Error generating explanation: {str(e)}"

# %% [markdown]
# ## Loading and analyzing results

# %%
def display_error_summary(df, model_column, explanation_column):

    for i in range(df.shape[0]):
        if(df.iloc[i]['label'] != df.iloc[i][model_column]):
            print(f"\nEMAIL :\n{df.iloc[i]['email']}")
            print(f"\n\nTRUE LABEL : {df.iloc[i]['label']}")
            print(f"\n\nPREDICTED LABEL : {df.iloc[i][model_column]}")
            print(f"\n\nEXPLANATION COLUMN :\n{df.iloc[i][explanation_column]}")

            print()
            print("-"*90)
            print()

# %%
def load_and_analyze_results(file_path, sheet_name="annotated_data", model_name='mistral'):
    """
    Load existing classification results and analyze errors.
    
    Args:
        file_path (str): Path to Excel file with results
        sheet_name (str): Sheet name containing the data
        model_column (str): Column name with model predictions
        
    Returns:
        pd.DataFrame: Error analysis results
    """

    model_column = f"{model_name}_results"
    explanation_column = f"{model_name}_explanation"
    
    # Load the data
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    
    # Validate required columns
    required_columns = ['email', 'label', model_column]
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        raise ValueError(f"Missing required columns: {missing_columns}")

    if(model_name == "mistral"):
        model, token = model2, token2
    elif(model_name == "gemma"):
        model, token = model1, token1
    elif(model_name == "llama"):
        model, token = model3, token3
    
    # Create Explanation column
    df[explanation_column] = df.apply(
                                        lambda row: explain_classification_error(
                                            model,
                                            token,
                                            email_content=row["email"],
                                            classification_prompt=original_prompt,
                                            predicted_label=row[model_column]
                                        ),
                                        axis=1
                                    )
    
    # Display comprehensive summary
    display_error_summary(df, model_column, explanation_column)

# %% [markdown]
# ## Error Explanation

# %% [markdown]
# ### Mistral error explanation

# %%
load_and_analyze_results(f"{path}/data/email_classification_annotated_data.xlsx", "Prompt-2 results", 'mistral')
# Out:
# EMAIL :
# Hello Saideep,
#
# Thank you for beginning the application for the job Data Scientist. We hope you’ll have time to return and complete it.
#
# If you decide not to apply, you can either delete the data or it will be automatically deleted after 30 days. We appreciate your interest and look forward to hearing from you soon!
#
# Sincerely,
# Ford Talent Acquisition Team
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : JOB
#
#
# EXPLANATION COLUMN :
# The email was classified as **JOB** because it directly concerns the status of a job application. The sender acknowledges that the recipient (Saideep) has begun an application for the position of **Data Scientist** and encourages them to complete it. This falls under the **JOB** category because it involves an **application confirmation**—a key indicator of a job-related communication as defined in the instructions.
#
# Key phrases that influenced this decision include:
# - *"Thank you for beginning the application for the job Data Scientist"*
# - *"We hope you’ll have time to return and complete it"*
# - *"If you decide not to apply..."*
#
# These phrases confirm that the email is about an **ongoing job application process**, which aligns with the rule:
# *"Classify an email as `JOB` if it concerns the status of a specific job application. Recipient of the mail will be informed about the status of their application. This includes notifications that a candidate has: Successfully applied for a job (only application confirmation)."*
#
# Since the email explicitly references an application in progress and provides instructions related to its completion, it clearly fits the **JOB** classification rather than **MEET** (no meeting request) or **OTHER** (not a general inquiry or unrelated content).
#
# ------------------------------------------------------------------------------------------

# %% [markdown]
# ### Gemma error explanation

# %%
load_and_analyze_results(f"{path}/data/email_classification_annotated_data.xlsx", "Prompt-2 results", 'gemma')
# Out:
# EMAIL :
# Hello Saideep,
#
# Thank you for your interest in joining the Embark team!  We are always on the look-out for passionate and talented future pack members to join us on our mission to improve the life and health of dogs.  Our hiring team will review your application and be in touch if your skills and qualifications match our needs.
#
# Learn more about our fantastic team, the science and discoveries we are embarking on, and the products we have launched @Embark.
#
# Thanks again for applying and have a great day!
#
# Embark Team
#
#
# TRUE LABEL : JOB
#
#
# PREDICTED LABEL : OTHER
#
#
# EXPLANATION COLUMN :
# **Why did you classify it as OTHER?**
#
# I classified the email as `OTHER` because it is a general acknowledgment of an application submission, not a notification regarding the status of a specific job application. The email confirms receipt of the application and states that the hiring team will review it. This is a standard automated response and doesn't communicate a decision (acceptance, rejection, interview invitation, etc.). It's an informational email, not a status update.
#
# The keywords "Thank you for your interest," "review your application," and "be in touch if your skills and qualifications match our needs" indicate a general acknowledgement of the application. There's no mention of an interview, assessment, or any other specific stage of the hiring process. The email also includes a link to learn more about the company, which is typical of a general communication rather than a status update.
#
# The rule that led to this decision is: "Only classify an email as JOB if it communicates a completed action related to the application status (e.g., application received, interview invitation, rejected, job offered). Do NOT classify emails with ongoing or vague updates (e.g., "Your application is under review") as JOB." This email falls under the "ongoing update" category as it only states the application is being reviewed, without providing a completed action or decision.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Hello Saideep,
#
# You might be a great fit for the new positions we just posted! We hope you're still interested in finding your dream job at Ford Motor Company. If so, we invite you to see if this might be the one. Learn more here:
#
# Administrative Assistant
#
# See all opportunities
#
# Sincerely,
# Ford Talent Acquisition Team
#
# If you do not want to receive these job notifications, or if you want to update your preferences, go to our career site.
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : JOB
#
#
# EXPLANATION COLUMN :
# **Why did you classify it as JOB?**
#
# I classified the email as `JOB` because it directly relates to the status of a job application. The email explicitly mentions "new positions" and invites the recipient to "see if this might be the one," implying a follow-up regarding potential employment opportunities. The phrase "dream job" further reinforces the connection to job seeking and application status.
#
# The keywords "Administrative Assistant," "opportunities," and "job notifications" are strong indicators that the email is about job openings and potential application status updates. The sender, "Ford Talent Acquisition Team," is a recruiting department, further solidifying the context of job applications.
#
# This decision aligns with the rule stating that an email should be classified as `JOB` if it concerns the status of a specific job application, including notifications about application receipt, interview invitations, or potential job offers. While not a direct interview invitation, the email is presenting new opportunities, which is a relevant update to a job seeker's application status and encourages further engagement.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Your Top Job matches from Jobright - July 31
# Explore this today's top matches, curated to align with your preferences, experiences, and skill sets.
# 	96%
# match score
#
# 3 minutes ago Be an early applicant
# Junior Data Scientist
# Power Digital Marketing / Marketing & Advertising · Late Stage
# Power Digital is a growth marketing firm fueled by technology and driven by a talented team of consultative marketers, creatives, analysts and technologists.
# RemoteRemote - United StatesFull-time
# APPLY NOW
# 	86%
# match score
#
# 1 hour ago Be an early applicant
# Data Science & Analytics Engineer
# Insperity / Enterprise Software,Human Resources,Service Industry · Public Company
# Insperity (formerly Administaff), a trusted advisor to America’s best businesses for more than 25 years, provides an array of human
# RemoteHouston, TXFull-time
# APPLY NOW
# 	83%
# match score
#
# 9 hours ago Be an early applicant
# Data Engineer
# Nomi Health / Finance,Health Care,Insurance,mHealth · Late Stage
# Nomi Health is a direct health company that aims to reduce the cost of health care for employers and patients.
# RemoteAustin, TexasFull-time
# APPLY NOW
# 	83%
# match score
#
# 1 hour ago Be an early applicant
# Business Intelligence Engineer II
# Chewy / E-Commerce,Pet,Retail · Public Company
# Chewy is a pet store that offers products, services, supplies, and prescriptions for pet parents and partners with online services.
# $113K/yr - $180K/yrOnsiteBellevue, WAFull-time
# APPLY NOW
# 	88%
# match score
#
# 6 hours ago Be an early applicant
# GenAI Data Scientist, Senior
# Deloitte / Accounting,Consulting,Financial Services,Legal,Professional Services,Risk Management · Late Stage
# Deloitte is a business consulting company that offers audit, consulting, financial advisory, and tax services.
# $103K/yr - $235K/yrHybridHouston, TXFull-time
# APPLY NOW
# View More Opportunities
# Happy Job Hunting,
# The Jobright.ai Team
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : JOB
#
#
# EXPLANATION COLUMN :
# The email was classified as `JOB` because it presents a curated list of "Top Job matches" from Jobright, directly addressing the recipient's potential job search needs. The email explicitly lists several job titles (Junior Data Scientist, Data Science & Analytics Engineer, Data Engineer, Business Intelligence Engineer II, GenAI Data Scientist, Senior) along with company names, locations, salary ranges, and application status indicators (e.g., "Late Stage," "Public Company," "Hybrid"). This indicates a notification of potential job opportunities aligned with the recipient's profile.
#
# Several keywords and phrases influenced this decision. "Top Job matches," "Junior Data Scientist," "Data Science," "Data Engineer," and the inclusion of company details and salary ranges all point towards job opportunities. The email's purpose is clearly to present potential job openings, which aligns directly with the `JOB` classification.
#
# The rule "Only classify an email as JOB if it communicates a completed action related to the application status (e.g., application received, interview invitation, rejected, job offered). Do NOT classify emails with ongoing or vague updates (e.g., "Your application is under review") as JOB" is not directly applicable here. Instead, the email presents a list of *potential* job matches, which is a more concrete action than a vague update. The email is informing the recipient of available job opportunities based on their profile, thus fitting the criteria for the `JOB` category.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Hey Jake!
# It's been way too long since we connected in person. Want to grab coffee sometime this week? I've got some exciting updates about the startup scene here, and I'd love to hear what you've been up to.
# Let me know what works for you!
# Cheers,
# Alex
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : MEET
#
#
# EXPLANATION COLUMN :
# The email was classified as `MEET` because the primary purpose of the email is to request a coffee meeting. The sender explicitly asks "Want to grab coffee sometime this week?". This clearly indicates a desire to schedule a meeting, even though the format is informal.
#
# The phrase "grab coffee" strongly implies an in-person meeting, but the instructions state that if a request for a "meeting" is made without specifying online or in-person, it should be classified as `MEET`. Since the email doesn't specify the meeting type, and the core intent is to connect in person, it falls under the `MEET` category.
#
# The rule "If an email mentions a 'meeting' but does not specify whether it is virtual or in-person, classify it as online meeting" is not applicable here because the email doesn't mention online meeting. However, the general instruction to classify requests for meetings as `MEET` when no specific type is mentioned is the key factor in this classification.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Hi Tom,
# We need to discuss the client situation immediately. Can you meet me in Conference Room B at 3 PM today? This requires immediate attention and can't wait.
# Thanks,
# Michelle
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : MEET
#
#
# EXPLANATION COLUMN :
# The email was classified as `MEET` because it explicitly requests a meeting. The phrase "Can you meet me" directly indicates a scheduling request. While the email doesn't specify the meeting format (online or in-person), the instructions state that if a request for a "meeting" is made without specifying the format, it should be classified as an online meeting.
#
# Therefore, the rule "If an email mentions a 'meeting' but does not specify whether it is virtual or in-person, classify it as an online meeting" directly led to the `MEET` classification. The core action of the email is a meeting request, and the lack of specification regarding the meeting's location defaults to an online meeting according to the provided guidelines.
#
# The email does not contain any information related to job applications (like application status, interviews, or rejections), thus ruling out the `JOB` category. It's a direct request for a meeting, making `MEET` the most appropriate classification based on the given options and rules.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Agent Smith,
# Your mission, should you choose to accept it: Meet me at the secret location (that café we love on 5th Street) this Saturday at 10 AM. Intel suggests they have new pastries that require immediate reconnaissance.
# This message will self-destruct in... well, it won't, but you get the idea.
# Agent Jones
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : MEET
#
#
# EXPLANATION COLUMN :
# The email was classified as `MEET` because it explicitly requests a meeting between Agent Smith and Agent Jones. The core of the email revolves around scheduling a rendezvous at a specific location ("that café we love on 5th Street") and time ("this Saturday at 10 AM"). This clearly indicates a desire to convene, which aligns with the definition of the `MEET` category.
#
# The phrase "Meet me" is a direct and unambiguous request for a meeting. While the location is physical, the instructions state that if a meeting is requested without specifying in-person or virtual, it should be classified as an online meeting. Given the context of the Agents and the nature of their work (implied to be clandestine and potentially requiring discretion), it's reasonable to infer that the meeting could be virtual, even though a physical location is mentioned. The email's purpose is to coordinate a time and place for a discussion, which falls under the umbrella of scheduling a meeting.
#
# The rule "If an email mentions a "meeting" but does not specify whether it is virtual or in-person, classify it as an online meeting" directly supports this classification. Since the email doesn't explicitly state "in-person" or "face-to-face," the default assumption, according to the instructions, is that the meeting is intended to be virtual. Therefore, the email fits the criteria for the `MEET` category.
#
#
#
#
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Dear Professor Williams,
# I hope this email finds you well. I would greatly appreciate the opportunity to meet with you in person to discuss my dissertation proposal on sustainable urban development.
# Would you have availability during your office hours next week? I anticipate our discussion would take approximately 30 minutes.
# Respectfully,
# David Park
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : MEET
#
#
# EXPLANATION COLUMN :
# The email was classified as `MEET` because the sender, David Park, explicitly requests a meeting with Professor Williams. The phrase "I would greatly appreciate the opportunity to meet with you in person" clearly indicates a desire for a meeting. While the email doesn't specify the *method* of the meeting (in-person or virtual), the instructions state that if a request mentions a "meeting" without specifying the format, it should be classified as an online meeting. Given the context of a dissertation proposal discussion, it's highly probable that the meeting would be conducted online, aligning with the classification rule.
#
# Furthermore, the email's purpose is to discuss a dissertation proposal, which is a common academic discussion that can easily be facilitated through virtual meetings. The request is for a discussion and consultation, making an online meeting a practical and convenient option. The email doesn't mention any job application status or other topics, further solidifying the `MEET` classification.
#
# The rule "If an email mentions a "meeting" but does not specify whether it is virtual or in-person, classify it as an online meeting" directly supports this decision. Since the email doesn't specify "in-person," and the context suggests a discussion that could readily occur online, the `MEET` classification is appropriate.
#
#
#
#
#
# ------------------------------------------------------------------------------------------

# %%
load_and_analyze_results(f"{path}/data/email_classification_annotated_data.xlsx", "Prompt-2 results", 'llama')
# Out:
# EMAIL :
# Dear Robert,
# My name is Patricia Gonzalez, and I'm the procurement director at Meridian Manufacturing. We're currently evaluating logistics partners for our East Coast distribution network, and Coastal Logistics came highly recommended by several industry contacts.
# I'd appreciate the opportunity to discuss our requirements and learn more about your capabilities. Would you be available for a 45-minute introductory call? I'm flexible with timing but generally prefer meetings between 9 AM and 3 PM EST on weekdays.
# Some topics I'd like to cover include your capacity for handling temperature-sensitive products, your technology integration capabilities, and your experience with automotive parts distribution.
# Please let me know a few times that work for you, and I'll send over a calendar invite.
# Thank you for your time.
# Best regards,
# Patricia Gonzalez
# Procurement Director
# Meridian Manufacturing
#
#
# TRUE LABEL : MEET
#
#
# PREDICTED LABEL : OTHER
#
#
# EXPLANATION COLUMN :
# The email was classified as `OTHER` because it is a request for a meeting to discuss business requirements and capabilities, specifically regarding logistics partnership. The sender, Patricia Gonzalez, is the procurement director at Meridian Manufacturing, and she is evaluating logistics partners for their East Coast distribution network.
#
# The specific parts of the email that led to this decision include the phrase "I'd appreciate the opportunity to discuss our requirements and learn more about your capabilities" and "Would you be available for a 45-minute introductory call?" Although the email mentions a meeting, it refers to a "call," which could be considered virtual. However, the email does not explicitly state that it is an online meeting. Nevertheless, according to the given instructions, if an email mentions a "meeting" but does not specify whether it is virtual or in-person, it should be classified as an online meeting. But in this context, the term "call" is used, which implies a virtual meeting. Still, the primary reason for the `OTHER` classification is that the email is related to a general business discussion rather than a job application or status update.
#
# The keywords or phrases that influenced this choice include "introductory call," "logistics partners," and "business requirements." The rule from the given instructions that led to this decision is that emails related to general job-related discussions or business inquiries should be classified as `OTHER`. Since this email is about discussing logistics partnership and not related to job application status, it falls under the `OTHER` category.
#
# ------------------------------------------------------------------------------------------
#
#
# EMAIL :
# Hello Saideep,
#
# Thank you for beginning the application for the job Data Scientist. We hope you’ll have time to return and complete it.
#
# If you decide not to apply, you can either delete the data or it will be automatically deleted after 30 days. We appreciate your interest and look forward to hearing from you soon!
#
# Sincerely,
# Ford Talent Acquisition Team
#
#
# TRUE LABEL : OTHER
#
#
# PREDICTED LABEL : JOB
#
#
# EXPLANATION COLUMN :
# I classified the email as `JOB` because it concerns the status of a specific job application. The email explicitly mentions that the recipient has begun the application for the job "Data Scientist" and provides instructions on how to complete it or have the data deleted if they decide not to apply.
#
# The specific parts of the email that led to this decision include the phrases "Thank you for beginning the application for the job Data Scientist" and "We hope you’ll have time to return and complete it." These phrases indicate that the email is related to the status of a job application, specifically an application confirmation. The keyword "application" is crucial in this context.
#
# The rule from the given instructions that led to this decision is: "Classify an email as `JOB` if it concerns the status of a specific job application... notifications that a candidate has: Successfully applied for a job (only application confirmation)." Although the application is not complete, the email confirms that the candidate has begun the application process, which aligns with the spirit of this rule. The email serves as a confirmation/notification related to the job application status.
#
# ------------------------------------------------------------------------------------------
